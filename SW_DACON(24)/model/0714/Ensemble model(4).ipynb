# %%
import pandas as pd   

train=pd.read_csv("/Users/withmocha/Desktop/DATA/SW DACON(24)/Data/main/train/0712/train data columns.csv",index_col=0)

train
# Out:
#                0          1          2          3          4          5  \
# 0     -10.680473 -10.065905  -8.485398  -8.471478  -8.938723  -9.573242
# 1     -11.071263 -11.079940 -10.551203 -10.089887  -9.634271  -9.297155
# 2     -11.061636 -10.900703  -9.897691  -9.627090  -9.460627  -9.390776
# 3     -10.501434  -9.739539  -8.956120  -9.592299 -10.143098 -10.398886
# 4     -11.117754 -11.013177 -10.541680 -10.596990 -10.668945 -10.714156
# ...          ...        ...        ...        ...        ...        ...
# 55433 -11.144724 -11.137963 -10.819232 -10.458742 -10.402115 -10.462618
# 55434 -10.425381  -9.859460  -9.212831  -9.264336  -9.338524  -9.558168
# 55435  -8.136928  -8.514102  -8.929909  -9.356843  -9.693064 -10.213511
# 55436 -10.992670 -10.891329 -10.557309 -10.454976 -10.429793 -10.488954
# 55437 -10.772964 -10.521650  -9.840327 -10.057259 -10.229515 -10.349794
#
#                6          7          8          9  ...      1007      1008  \
# ...

# %%
train.isnull().sum()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 1012     0
# 1013     0
# 1014     0
# 1015     0
# label    0
# Length: 1017, dtype: int64

# %%
train_y=pd.DataFrame(train['label'])

# %%
train_y
# Out:
#       label
# 0      fake
# 1      fake
# 2      real
# 3      real
# 4      real
# ...     ...
# 55433  fake
# 55434  fake
# 55435  real
# 55436  fake
# 55437  fake
#
# [55438 rows x 1 columns]

# %%
train_y.iloc[2,0]
# Out:
# 'real'

# %%
Y=pd.DataFrame(index=range(train_y.shape[0]),columns=['label'])
Y.columns
# Out:
# Index(['label'], dtype='object')

# %%
for i in range(train.shape[0]):     
    if train_y.iloc[i,0]=='real':
        Y.iloc[i,0]=1.0
    elif train_y.iloc[i,0]=='fake':
        Y.iloc[i,0]=0.0

# %%
Y
# Out:
#       label
# 0       0.0
# 1       0.0
# 2       1.0
# 3       1.0
# 4       1.0
# ...     ...
# 55433   0.0
# 55434   0.0
# 55435   1.0
# 55436   0.0
# 55437   0.0
#
# [55438 rows x 1 columns]

# %%
train_y.isnull().sum()
# Out:
# label    0
# dtype: int64

# %%
train_x=train.drop(columns=['label'])

# %%
train_x
# Out:
#                0          1          2          3          4          5  \
# 0     -10.680473 -10.065905  -8.485398  -8.471478  -8.938723  -9.573242
# 1     -11.071263 -11.079940 -10.551203 -10.089887  -9.634271  -9.297155
# 2     -11.061636 -10.900703  -9.897691  -9.627090  -9.460627  -9.390776
# 3     -10.501434  -9.739539  -8.956120  -9.592299 -10.143098 -10.398886
# 4     -11.117754 -11.013177 -10.541680 -10.596990 -10.668945 -10.714156
# ...          ...        ...        ...        ...        ...        ...
# 55433 -11.144724 -11.137963 -10.819232 -10.458742 -10.402115 -10.462618
# 55434 -10.425381  -9.859460  -9.212831  -9.264336  -9.338524  -9.558168
# 55435  -8.136928  -8.514102  -8.929909  -9.356843  -9.693064 -10.213511
# 55436 -10.992670 -10.891329 -10.557309 -10.454976 -10.429793 -10.488954
# 55437 -10.772964 -10.521650  -9.840327 -10.057259 -10.229515 -10.349794
#
#                6          7          8          9  ...      1006      1007  \
# ...

# %%
from sklearn.feature_selection import VarianceThreshold

# 분산이 낮은 특성 제거
#selector = VarianceThreshold(threshold=0.1)
#train_x = pd.DataFrame(selector.fit_transform(train_x))
#train_x

# %%
from sklearn.decomposition import PCA

# 주성분 분석을 통한 차원 축소
#pca = PCA(n_components=300)  
#train_x = pd.DataFrame(pca.fit_transform(train_x))

# %%
train_x
# Out:
#                0          1          2          3          4          5  \
# 0     -10.680473 -10.065905  -8.485398  -8.471478  -8.938723  -9.573242
# 1     -11.071263 -11.079940 -10.551203 -10.089887  -9.634271  -9.297155
# 2     -11.061636 -10.900703  -9.897691  -9.627090  -9.460627  -9.390776
# 3     -10.501434  -9.739539  -8.956120  -9.592299 -10.143098 -10.398886
# 4     -11.117754 -11.013177 -10.541680 -10.596990 -10.668945 -10.714156
# ...          ...        ...        ...        ...        ...        ...
# 55433 -11.144724 -11.137963 -10.819232 -10.458742 -10.402115 -10.462618
# 55434 -10.425381  -9.859460  -9.212831  -9.264336  -9.338524  -9.558168
# 55435  -8.136928  -8.514102  -8.929909  -9.356843  -9.693064 -10.213511
# 55436 -10.992670 -10.891329 -10.557309 -10.454976 -10.429793 -10.488954
# 55437 -10.772964 -10.521650  -9.840327 -10.057259 -10.229515 -10.349794
#
#                6          7          8          9  ...      1006      1007  \
# ...

# %%
from sklearn.preprocessing import StandardScaler,RobustScaler

scaler=RobustScaler()

train_x=pd.DataFrame(scaler.fit_transform(train_x))
train_x
# Out:
#             0         1         2         3         4         5         6     \
# 0       0.875701  1.351565  2.097948  2.224098  1.633642  0.765481  0.562562
# 1      -0.528780 -0.845305 -0.728674 -0.136786  0.570881  1.199932  1.364931
# 2      -0.494179 -0.456994  0.165520  0.538328  0.836200  1.052611  0.961611
# 3       1.519161  2.058624  1.453863  0.589079 -0.206581 -0.533753 -0.337211
# 4      -0.695865 -0.700666 -0.715644 -0.876531 -1.010049 -1.029864 -0.876730
# ...          ...       ...       ...       ...       ...       ...       ...
# 55433  -0.792793 -0.971010 -1.095417 -0.674859 -0.602345 -0.634043 -0.498115
# 55434   1.792492  1.798821  1.102608  1.067502  1.022767  0.789202  0.467609
# 55435  10.017083  4.713488  1.489727  0.932556  0.481049 -0.242047 -0.994932
# 55436  -0.246320 -0.436686 -0.737029 -0.669366 -0.644636 -0.675484 -0.725948
# 55437   0.543293  0.364210  0.244011 -0.089189 -0.338622 -0.456503 -0.556475
#
# ...

# %%
train_x
# Out:
#             0         1         2         3         4         5         6     \
# 0       0.875701  1.351565  2.097948  2.224098  1.633642  0.765481  0.562562
# 1      -0.528780 -0.845305 -0.728674 -0.136786  0.570881  1.199932  1.364931
# 2      -0.494179 -0.456994  0.165520  0.538328  0.836200  1.052611  0.961611
# 3       1.519161  2.058624  1.453863  0.589079 -0.206581 -0.533753 -0.337211
# 4      -0.695865 -0.700666 -0.715644 -0.876531 -1.010049 -1.029864 -0.876730
# ...          ...       ...       ...       ...       ...       ...       ...
# 55433  -0.792793 -0.971010 -1.095417 -0.674859 -0.602345 -0.634043 -0.498115
# 55434   1.792492  1.798821  1.102608  1.067502  1.022767  0.789202  0.467609
# 55435  10.017083  4.713488  1.489727  0.932556  0.481049 -0.242047 -0.994932
# 55436  -0.246320 -0.436686 -0.737029 -0.669366 -0.644636 -0.675484 -0.725948
# 55437   0.543293  0.364210  0.244011 -0.089189 -0.338622 -0.456503 -0.556475
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_x, Y, test_size=0.3, shuffle=True)

# %%
X_train
# Out:
#            0         1         2         3         4         5         6     \
# 43582 -0.187876  0.069420  0.041957 -0.020484  0.095199  0.018850 -0.395113
# 3161  -0.157151 -0.338301 -0.508445 -0.445635 -0.378918 -0.240327  0.116212
# 21885 -0.638496 -0.710231 -0.629244 -0.125404  0.560700  1.148451  1.367926
# 46123  0.014332 -0.098880 -0.093264 -0.319613 -0.521100 -0.756787 -0.904349
# 15677  1.191583  1.005547  0.724410  0.553547  0.496375  0.417835  0.413109
# ...         ...       ...       ...       ...       ...       ...       ...
# 15876  0.128887 -0.006152 -0.215882 -0.392606 -0.528411 -0.719275 -0.882441
# 20011  0.289973  0.776385  1.071985  1.052224  1.157804  1.329444  1.226718
# 942   -0.744060 -0.869781 -1.055233 -0.950415 -0.621875 -0.358872 -0.299851
# 28885 -0.729700 -0.782232 -1.063987 -1.133985 -1.065534 -0.924343 -0.748745
# 21280 -0.428096 -0.522006 -0.737076 -0.816762 -0.817243 -0.821386 -0.860156
#
# ...

# %%
y_train
# Out:
#       label
# 43582   1.0
# 3161    1.0
# 21885   1.0
# 46123   0.0
# 15677   0.0
# ...     ...
# 15876   0.0
# 20011   1.0
# 942     1.0
# 28885   1.0
# 21280   1.0
#
# [38806 rows x 1 columns]

# %%
X_test
# Out:
#            0         1         2         3         4         5         6     \
# 40689  0.491927  0.264641  0.111656  0.096832  0.333333  0.523554  0.407431
# 21201 -0.092794 -0.314513 -0.083833 -0.165302 -0.361086 -0.603091 -0.661563
# 49146  0.672788  1.015589  1.501709  1.596871  1.772290  1.811624  1.625539
# 6952  -0.474264 -0.543801 -0.661364 -0.368744  0.046244  0.469075  0.782898
# 29206 -0.217441 -0.428562 -0.379801 -0.383385 -0.446948 -0.533922 -0.578714
# ...         ...       ...       ...       ...       ...       ...       ...
# 46656 -0.506568 -0.551299 -0.951932 -0.824755 -0.688334 -0.562590 -0.433073
# 17141 -0.568057 -0.795080 -0.831023 -0.821084 -0.656479 -0.362019  0.451676
# 19851 -0.366060 -0.030565  0.464905  0.095634 -0.199312 -0.703880 -0.340537
# 20252  1.464509  0.442104  0.440778  0.376672  0.297240  0.240470  0.482297
# 47679 -0.293767 -0.424824 -0.484306 -0.324900  0.278642  0.744792  0.778441
#
# ...

# %%
import tensorflow as tf
import numpy as np 

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = np.array(y_train).astype(np.float32)


X_train_tensor = tf.convert_to_tensor(X_train)
X_test_tensor = tf.convert_to_tensor(X_test)

# %%
import tensorflow as tf

x_train = tf.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
x_test = tf.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Bidirectional, Conv1D, MaxPooling1D, Flatten, concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.optimizers import Adamax
from tensorflow.keras.activations import elu
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer, MultiHeadAttention, LayerNormalization
from tensorflow.keras.layers import Dropout
from tensorflow.keras.regularizers import l2



def scheduler(epoch, lr):
    if epoch < 10:
        return np.float32(lr)
    else:
        return np.float32(lr * tf.math.exp(-0.1))



class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential(
            [Dense(ff_dim, activation="elu"), Dense(embed_dim),]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        return self.layernorm2(out1 + ffn_output)


input_layer = Input(shape=(x_train.shape[1], x_train.shape[2]))


cnn = Conv1D(filters=64, kernel_size=5, activation='elu', kernel_regularizer=l2(0.01))(input_layer)
cnn = Dropout(0.5)(cnn)
cnn = Conv1D(filters=32, kernel_size=5, activation='elu', kernel_regularizer=l2(0.01))(cnn)
cnn = Dropout(0.5)(cnn)
cnn = Conv1D(filters=16, kernel_size=5, activation='elu', kernel_regularizer=l2(0.01))(cnn)
cnn = MaxPooling1D(pool_size=2)(cnn)
cnn = Flatten()(cnn)


lstm = Bidirectional(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.01)))(input_layer)
lstm = Dropout(0.5)(lstm)
lstm = Bidirectional(LSTM(16, return_sequences=True, kernel_regularizer=l2(0.01)))(lstm)
lstm = Dropout(0.5)(lstm)
lstm = Bidirectional(LSTM(8, return_sequences=False, kernel_regularizer=l2(0.01)))(lstm)


transformer = TransformerBlock(embed_dim=x_train.shape[2], num_heads=4, ff_dim=32)(input_layer, training=True)
transformer = Flatten()(transformer)


combined = concatenate([cnn, lstm, transformer])


dense = Dense(16, activation='elu', kernel_regularizer=l2(0.01))(combined)
dense = Dropout(0.5)(dense)
dense = Dense(8, activation='elu', kernel_regularizer=l2(0.01))(dense)
dense = Dropout(0.5)(dense)
output = Dense(1, activation='sigmoid')(dense)


model = Model(inputs=input_layer, outputs=output)


model.compile(optimizer=Adamax(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])


early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True)
lr_scheduler = LearningRateScheduler(scheduler)

model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 1016, 1)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 1012, 64)  │        384 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 1012, 64)  │          0 │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 1008, 32)  │     10,272 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
training_record = model.fit(x_train, y_train,
                    epochs=100,
                    batch_size=128,
                    callbacks=[model_checkpoint, lr_scheduler,early_stopping],  
                    validation_split=0.3,
                    shuffle=True,
                    verbose=1)
# Out:
# Epoch 1/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.7237 - loss: 2.5626 - val_accuracy: 0.7779 - val_loss: 1.0573 - learning_rate: 0.0010
# Epoch 2/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 471s 2s/step - accuracy: 0.7660 - loss: 0.9619 - val_accuracy: 0.7820 - val_loss: 0.6952 - learning_rate: 0.0010
# Epoch 3/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 445s 2s/step - accuracy: 0.7812 - loss: 0.6866 - val_accuracy: 0.7850 - val_loss: 0.5875 - learning_rate: 0.0010
# Epoch 4/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 397s 2s/step - accuracy: 0.7873 - loss: 0.6036 - val_accuracy: 0.7925 - val_loss: 0.5450 - learning_rate: 0.0010
# Epoch 5/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 398s 2s/step - accuracy: 0.7902 - loss: 0.5671 - val_accuracy: 0.7963 - val_loss: 0.5205 - learning_rate: 0.0010
# Epoch 6/100
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 417s 2s/step - accuracy: 0.8092 - loss: 0.5415 - val_accuracy: 0.8239 - val_loss: 0.4838 - learning_rate: 0.0010
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.plot(training_record.history["loss"], label="Training Loss")
plt.plot(training_record.history["val_loss"], label="Validation Loss")
plt.legend()
fig.suptitle("Loss")
plt.show()

# %%
y_pred_probs = model.predict(X_test)
# Out:
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 86s 165ms/step

# %%
y_pred_probs
# Out:
# array([[0.6975848 ],
#        [0.49121812],
#        [0.35294616],
#        ...,
#        [0.02882891],
#        [0.68669754],
#        [0.97538066]], dtype=float32)

# %%
y_pred_probs[16631][0]
# Out:
# 0.97538066

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

y_pred = (y_pred_probs > 0.5).astype('int32')

# %%
y_pred
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [0],
#        [1],
#        [1]], dtype=int32)

# %%
y_test=np.array(y_test).astype('int32')

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 8)) 
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)  
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)  
plt.ylabel('True Positive Rate', fontsize=16)  
plt.title('Receiver Operating Characteristic (ROC)', fontsize=18)  
plt.legend(loc="lower right", fontsize=14)  
plt.grid(True)  
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt


precision, recall, thresholds = precision_recall_curve(y_test, y_pred_probs)


average_precision = average_precision_score(y_test, y_pred_probs)

plt.figure(figsize=(8, 6))  
plt.plot(recall, precision, label='PRC curve (AP = {:.2f})'.format(average_precision), linewidth=2, color='blue')  
plt.xlabel('Recall', fontsize=14)  
plt.ylabel('Precision', fontsize=14)  
plt.title('Precision-Recall Curve', fontsize=16)  
plt.legend(loc="lower left", fontsize=12)  
plt.grid(True)  
plt.xlim([0.0, 1.0])  
plt.ylim([0.0, 1.05])  
plt.show()

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy_score: {accuracy}')
# Out:
# accuracy_score: 0.8464405964405964

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print('confusion matrix:')
print(conf_matrix)
# Out:
# confusion matrix:
# [[6838 1569]
#  [ 985 7240]]

# %%
class_report = classification_report(y_test, y_pred, target_names=['Class 0', 'Class 1'])
print('classification_report')
print(class_report)
# Out:
# classification_report
#               precision    recall  f1-score   support
#
#      Class 0       0.87      0.81      0.84      8407
#      Class 1       0.82      0.88      0.85      8225
#
#     accuracy                           0.85     16632
#    macro avg       0.85      0.85      0.85     16632
# weighted avg       0.85      0.85      0.85     16632

# %%
model.save('voice detection model 0715(1).keras')

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Layer, Dense, MultiHeadAttention, LayerNormalization
import numpy as np

# 사용자 정의 TransformerBlock 레이어 정의
class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super(TransformerBlock, self).__init__(**kwargs)
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential(
            [Dense(ff_dim, activation="relu"), Dense(embed_dim),]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        return self.layernorm2(out1 + ffn_output)

# %%
# 모델 경로
model_path = '/Users/withmocha/Desktop/visual studio code/SW_DACON(24)/model/0714/best_model.keras'  # 저장된 모델 파일 경로

# 저장된 모델 불러오기
loaded_model = load_model(model_path, custom_objects={'TransformerBlock': TransformerBlock})

# 모델 요약 출력
loaded_model.summary()
# Out:
# /opt/anaconda3/envs/conda_cpu/lib/python3.12/site-packages/keras/src/layers/layer.py:361: UserWarning: `build()` was called on layer 'transformer_block', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Model: "functional_26"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_16      │ (None, 1016, 1)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
y_pred_probs = model.predict(X_test)
# Out:
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 109s 210ms/step

# %%
y_pred = (y_pred_probs > 0.5).astype('int32')

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy_score: {accuracy}')
# Out:
# accuracy_score: 0.8464405964405964
