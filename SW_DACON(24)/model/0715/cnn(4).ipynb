# %%
import pandas as pd   

train=pd.read_csv("/Users/withmocha/Desktop/DATA/SW DACON(24)/Data/main/train/0712/train data columns.csv",index_col=0)

train
# Out:
#                0          1          2          3          4          5  \
# 0     -10.680473 -10.065905  -8.485398  -8.471478  -8.938723  -9.573242
# 1     -11.071263 -11.079940 -10.551203 -10.089887  -9.634271  -9.297155
# 2     -11.061636 -10.900703  -9.897691  -9.627090  -9.460627  -9.390776
# 3     -10.501434  -9.739539  -8.956120  -9.592299 -10.143098 -10.398886
# 4     -11.117754 -11.013177 -10.541680 -10.596990 -10.668945 -10.714156
# ...          ...        ...        ...        ...        ...        ...
# 55433 -11.144724 -11.137963 -10.819232 -10.458742 -10.402115 -10.462618
# 55434 -10.425381  -9.859460  -9.212831  -9.264336  -9.338524  -9.558168
# 55435  -8.136928  -8.514102  -8.929909  -9.356843  -9.693064 -10.213511
# 55436 -10.992670 -10.891329 -10.557309 -10.454976 -10.429793 -10.488954
# 55437 -10.772964 -10.521650  -9.840327 -10.057259 -10.229515 -10.349794
#
#                6          7          8          9  ...      1007      1008  \
# 0      -9.778496  -9.528599  -9.170987  -8.849465  ... -0.322508 -0.087017
# 1      -9.277541  -9.482996  -9.715906 -10.094424  ... -0.286983  0.044365
# 2      -9.529352  -9.783495 -10.150701 -10.327344  ...  0.084898  0.158464
# 3     -10.340263 -10.351754 -10.469296 -10.385562  ... -0.535377  0.416520
# 4     -10.677109 -10.532436 -10.372413 -10.261147  ... -0.007236  0.113250
# ...          ...        ...        ...        ...  ...       ...       ...
# 55433 -10.440723 -10.395901 -10.475930 -10.594594  ... -0.305863  0.020189
# 55434  -9.837779 -10.059920 -10.196332 -10.262708  ... -0.343358 -0.430669
# 55435 -10.750908 -10.973743 -11.060165 -11.075549  ...  0.033486  0.628226
# 55436 -10.582969 -10.744830 -10.849541 -10.596731  ... -0.632286  0.220390
# 55437 -10.477160 -10.586072 -10.613735 -10.599486  ...  0.301742  0.461116
#
#            1009      1010      1011      1012      1013      1014      1015  \
# 0      0.304063  0.404823  0.479159  0.535449  0.511438  0.202025  0.074921
# 1      0.068283  0.268024  0.378609  0.477951  0.543279  0.465428  0.377558
# 2     -0.037385 -0.031830 -0.065905 -0.144708 -0.238556 -0.262587 -0.109534
# 3      0.387058  0.726899  0.558501  0.497426  0.449314  0.332968  0.456198
# 4      0.147934  0.123936  0.134960  0.118806  0.215570  0.201303  0.227695
# ...         ...       ...       ...       ...       ...       ...       ...
# 55433  0.080815  0.032809 -0.131100 -0.412744 -0.478068 -0.421102 -0.405390
# 55434 -0.537894 -0.542315 -0.594209 -0.467926 -0.462328 -0.471181 -0.395152
# 55435  0.426825  0.151324  0.045645  0.201020  0.437524  0.442280  0.383002
# 55436  0.238211  0.220074  0.083456  0.072693  0.168384  0.335541  0.345256
# 55437  0.283341  0.426181  0.479992  0.518039  0.563831  0.723271  0.802327
#
#        label
# 0       fake
# 1       fake
# 2       real
# 3       real
# 4       real
# ...      ...
# 55433   fake
# 55434   fake
# 55435   real
# 55436   fake
# 55437   fake
#
# [55438 rows x 1017 columns]

# %%
train.isnull().sum()
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 1012     0
# 1013     0
# 1014     0
# 1015     0
# label    0
# Length: 1017, dtype: int64

# %%
train_y=pd.DataFrame(train['label'])

# %%
train_y
# Out:
#       label
# 0      fake
# 1      fake
# 2      real
# 3      real
# 4      real
# ...     ...
# 55433  fake
# 55434  fake
# 55435  real
# 55436  fake
# 55437  fake
#
# [55438 rows x 1 columns]

# %%
train_y.iloc[2,0]
# Out:
# 'real'

# %%
Y=pd.DataFrame(index=range(train_y.shape[0]),columns=['label'])
Y.columns
# Out:
# Index(['label'], dtype='object')

# %%
for i in range(train.shape[0]):     
    if train_y.iloc[i,0]=='real':
        Y.iloc[i,0]=1.0
    elif train_y.iloc[i,0]=='fake':
        Y.iloc[i,0]=0.0

# %%
Y
# Out:
#       label
# 0       0.0
# 1       0.0
# 2       1.0
# 3       1.0
# 4       1.0
# ...     ...
# 55433   0.0
# 55434   0.0
# 55435   1.0
# 55436   0.0
# 55437   0.0
#
# [55438 rows x 1 columns]

# %%
train_y.isnull().sum()
# Out:
# label    0
# dtype: int64

# %%
train_x=train.drop(columns=['label'])

# %%
train_x
# Out:
#                0          1          2          3          4          5  \
# 0     -10.680473 -10.065905  -8.485398  -8.471478  -8.938723  -9.573242
# 1     -11.071263 -11.079940 -10.551203 -10.089887  -9.634271  -9.297155
# 2     -11.061636 -10.900703  -9.897691  -9.627090  -9.460627  -9.390776
# 3     -10.501434  -9.739539  -8.956120  -9.592299 -10.143098 -10.398886
# 4     -11.117754 -11.013177 -10.541680 -10.596990 -10.668945 -10.714156
# ...          ...        ...        ...        ...        ...        ...
# 55433 -11.144724 -11.137963 -10.819232 -10.458742 -10.402115 -10.462618
# 55434 -10.425381  -9.859460  -9.212831  -9.264336  -9.338524  -9.558168
# 55435  -8.136928  -8.514102  -8.929909  -9.356843  -9.693064 -10.213511
# 55436 -10.992670 -10.891329 -10.557309 -10.454976 -10.429793 -10.488954
# 55437 -10.772964 -10.521650  -9.840327 -10.057259 -10.229515 -10.349794
#
#                6          7          8          9  ...      1006      1007  \
# 0      -9.778496  -9.528599  -9.170987  -8.849465  ... -0.453353 -0.322508
# 1      -9.277541  -9.482996  -9.715906 -10.094424  ... -0.193274 -0.286983
# 2      -9.529352  -9.783495 -10.150701 -10.327344  ...  0.133401  0.084898
# 3     -10.340263 -10.351754 -10.469296 -10.385562  ... -0.547253 -0.535377
# 4     -10.677109 -10.532436 -10.372413 -10.261147  ...  0.029022 -0.007236
# ...          ...        ...        ...        ...  ...       ...       ...
# 55433 -10.440723 -10.395901 -10.475930 -10.594594  ... -0.546889 -0.305863
# 55434  -9.837779 -10.059920 -10.196332 -10.262708  ... -0.281078 -0.343358
# 55435 -10.750908 -10.973743 -11.060165 -11.075549  ...  0.005537  0.033486
# 55436 -10.582969 -10.744830 -10.849541 -10.596731  ... -0.634200 -0.632286
# 55437 -10.477160 -10.586072 -10.613735 -10.599486  ...  0.297821  0.301742
#
#            1008      1009      1010      1011      1012      1013      1014  \
# 0     -0.087017  0.304063  0.404823  0.479159  0.535449  0.511438  0.202025
# 1      0.044365  0.068283  0.268024  0.378609  0.477951  0.543279  0.465428
# 2      0.158464 -0.037385 -0.031830 -0.065905 -0.144708 -0.238556 -0.262587
# 3      0.416520  0.387058  0.726899  0.558501  0.497426  0.449314  0.332968
# 4      0.113250  0.147934  0.123936  0.134960  0.118806  0.215570  0.201303
# ...         ...       ...       ...       ...       ...       ...       ...
# 55433  0.020189  0.080815  0.032809 -0.131100 -0.412744 -0.478068 -0.421102
# 55434 -0.430669 -0.537894 -0.542315 -0.594209 -0.467926 -0.462328 -0.471181
# 55435  0.628226  0.426825  0.151324  0.045645  0.201020  0.437524  0.442280
# 55436  0.220390  0.238211  0.220074  0.083456  0.072693  0.168384  0.335541
# 55437  0.461116  0.283341  0.426181  0.479992  0.518039  0.563831  0.723271
#
#            1015
# 0      0.074921
# 1      0.377558
# 2     -0.109534
# 3      0.456198
# 4      0.227695
# ...         ...
# 55433 -0.405390
# 55434 -0.395152
# 55435  0.383002
# 55436  0.345256
# 55437  0.802327
#
# [55438 rows x 1016 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

# 분산이 낮은 특성 제거
#selector = VarianceThreshold(threshold=0.1)
#train_x = pd.DataFrame(selector.fit_transform(train_x))
#train_x

# %%
from sklearn.decomposition import PCA

# 주성분 분석을 통한 차원 축소
#pca = PCA(n_components=300)  
#train_x = pd.DataFrame(pca.fit_transform(train_x))

# %%
train_x
# Out:
#                0          1          2          3          4          5  \
# 0     -10.680473 -10.065905  -8.485398  -8.471478  -8.938723  -9.573242
# 1     -11.071263 -11.079940 -10.551203 -10.089887  -9.634271  -9.297155
# 2     -11.061636 -10.900703  -9.897691  -9.627090  -9.460627  -9.390776
# 3     -10.501434  -9.739539  -8.956120  -9.592299 -10.143098 -10.398886
# 4     -11.117754 -11.013177 -10.541680 -10.596990 -10.668945 -10.714156
# ...          ...        ...        ...        ...        ...        ...
# 55433 -11.144724 -11.137963 -10.819232 -10.458742 -10.402115 -10.462618
# 55434 -10.425381  -9.859460  -9.212831  -9.264336  -9.338524  -9.558168
# 55435  -8.136928  -8.514102  -8.929909  -9.356843  -9.693064 -10.213511
# 55436 -10.992670 -10.891329 -10.557309 -10.454976 -10.429793 -10.488954
# 55437 -10.772964 -10.521650  -9.840327 -10.057259 -10.229515 -10.349794
# 11184  0.285286 -0.260044 -0.778863  ...  1.748501  1.587866  1.665929
# 24010  0.116889 -0.816991 -1.611591  ...  0.279609 -0.176611 -0.187623
# 1611   0.832110  1.082677  1.327389  ...  0.501890  0.578683  0.255215
# 30458  0.599359  0.353661  0.220817  ... -0.390728 -0.815647 -1.524546
# 19528 -0.854849 -0.665772 -0.717473  ...  0.943825  0.995792  1.035687
#
#            1009      1010      1011      1012      1013      1014      1015
# 55311 -0.899337  0.191699  0.739356  1.274053  1.565584  1.658742  1.559566
# 28253  0.961654  1.092585  1.229278  0.999649  0.897586  0.884802  1.075279
# 50184  0.592261 -0.131043 -0.467383 -0.195671  0.411276  0.575167  0.535341
# 42768  0.679794  0.500561  0.416029  0.418364  0.386259  0.350746  0.282917
# 19137 -0.420515 -0.671098 -0.867359 -0.348958  0.023497  0.114178  0.179745
# ...         ...       ...       ...       ...       ...       ...       ...
# 11184  1.773677  0.889169  0.382406  0.441151  0.720091  0.984349  1.131753
# 24010 -0.844685 -1.083456 -0.777845  0.371250  1.294593  1.461326  1.028638
# 1611   0.351560 -0.204508 -0.485082 -0.264539  0.043911  0.092768 -0.028203
# 30458 -1.979861 -2.343051 -2.256885 -2.033088 -1.976688 -1.844707 -1.669443
# 19528  1.034716  0.653103  0.543627  0.468418  0.328266  0.313544  0.141377
#
# [16632 rows x 1016 columns]

# %%
import tensorflow as tf
import numpy as np 

X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)
y_train = np.array(y_train).astype(np.float32)


X_train_tensor = tf.convert_to_tensor(X_train)
X_test_tensor = tf.convert_to_tensor(X_test)

# %%
import tensorflow as tf

x_train = tf.reshape(X_train,(X_train.shape[0],X_train.shape[1],1))
x_test = tf.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.optimizers import Adamax
import tensorflow as tf
import numpy as np

def scheduler(epoch, lr):
    if epoch < 10:
        return np.float32(lr)
    else:
        return np.float32(lr * tf.math.exp(-0.1))

input_layer = Input(shape=(x_train.shape[1], x_train.shape[2]))

cnn = Conv1D(filters=32, kernel_size=3, activation='elu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(input_layer)
cnn = BatchNormalization()(cnn)
cnn = MaxPooling1D(pool_size=2)(cnn)
cnn = Dropout(0.3)(cnn)

cnn = Conv1D(filters=16, kernel_size=3, activation='elu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(cnn)
cnn = BatchNormalization()(cnn)
cnn = MaxPooling1D(pool_size=2)(cnn)
cnn = Dropout(0.3)(cnn)

cnn = Conv1D(filters=8, kernel_size=3, activation='elu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(cnn)
cnn = BatchNormalization()(cnn)
cnn = MaxPooling1D(pool_size=2)(cnn)
cnn = Dropout(0.3)(cnn)

cnn = Flatten()(cnn)

dense = Dense(4, activation='elu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(cnn)
dense = Dropout(0.3)(dense)
output = Dense(1, activation='sigmoid')(dense)

model = Model(inputs=input_layer, outputs=output)

model.compile(optimizer=Adamax(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model(3).keras', save_best_only=True)
lr_scheduler = LearningRateScheduler(scheduler)

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 1016, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 1014, 32)       │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 1014, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 507, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 507, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 505, 16)        │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 505, 16)        │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 252, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 252, 16)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 250, 8)         │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 250, 8)         │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 125, 8)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 125, 8)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │         4,004 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 4)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,305 (24.63 KB)
#  Trainable params: 6,193 (24.19 KB)
#  Non-trainable params: 112 (448.00 B)

# %%
training_record = model.fit(x_train, y_train,
                    epochs=500,
                    batch_size=4,
                    callbacks=[model_checkpoint, lr_scheduler,early_stopping],  
                    validation_split=0.3,
                    shuffle=True,
                    verbose=1)
# Out:
# Epoch 1/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.7446 - loss: 0.7711 - val_accuracy: 0.8230 - val_loss: 0.4614 - learning_rate: 0.0030
# Epoch 2/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - accuracy: 0.7967 - loss: 0.5066 - val_accuracy: 0.8028 - val_loss: 0.4937 - learning_rate: 0.0030
# Epoch 3/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.8094 - loss: 0.4860 - val_accuracy: 0.8226 - val_loss: 0.4417 - learning_rate: 0.0030
# Epoch 4/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - accuracy: 0.8084 - loss: 0.4884 - val_accuracy: 0.8328 - val_loss: 0.4435 - learning_rate: 0.0030
# Epoch 5/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0.8103 - loss: 0.4821 - val_accuracy: 0.8165 - val_loss: 0.4515 - learning_rate: 0.0030
# Epoch 6/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 30s 4ms/step - accuracy: 0
500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - accuracy: 0.8321 - loss: 0.4171 - val_accuracy: 0.8436 - val_loss: 0.3817 - learning_rate: 4.0601e-04
# Epoch 31/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 35s 5ms/step - accuracy: 0.8302 - loss: 0.4240 - val_accuracy: 0.8501 - val_loss: 0.3731 - learning_rate: 3.6737e-04
# Epoch 32/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8340 - loss: 0.4179 - val_accuracy: 0.8562 - val_loss: 0.3729 - learning_rate: 3.3241e-04
# Epoch 33/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 6ms/step - accuracy: 0.8361 - loss: 0.4179 - val_accuracy: 0.8563 - val_loss: 0.3693 - learning_rate: 3.0078e-04
# Epoch 34/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - accuracy: 0.8374 - loss: 0.4173 - val_accuracy: 0.8548 - val_loss: 0.3712 - learning_rate: 2.7215e-04
# Epoch 35/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - accuracy: 0.8315 - loss: 0.4189 - val_accuracy: 0.8581 - val_loss: 0.3686 - learning_rate: 2.4626e-04
# Epoch 36/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8339 - loss: 0.4226 - val_accuracy: 0.8576 - val_loss: 0.3659 - learning_rate: 2.2282e-04
# Epoch 37/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - accuracy: 0.8385 - loss: 0.4123 - val_accuracy: 0.8596 - val_loss: 0.3680 - learning_rate: 2.0162e-04
# Epoch 38/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8417 - loss: 0.4108 - val_accuracy: 0.8604 - val_loss: 0.3634 - learning_rate: 1.8243e-04
# Epoch 39/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8392 - loss: 0.4105 - val_accuracy: 0.8578 - val_loss: 0.3637 - learning_rate: 1.6507e-04
# Epoch 40/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8354 - loss: 0.4161 - val_accuracy: 0.8592 - val_loss: 0.3665 - learning_rate: 1.4936e-04
# Epoch 41/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - accuracy: 0.8359 - loss: 0.4127 - val_accuracy: 0.8593 - val_loss: 0.3646 - learning_rate: 1.3515e-04
# Epoch 42/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 34s 5ms/step - accuracy: 0.8404 - loss: 0.4076 - val_accuracy: 0.8554 - val_loss: 0.3695 - learning_rate: 1.2229e-04
# Epoch 43/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 35s 5ms/step - accuracy: 0.8389 - loss: 0.4106 - val_accuracy: 0.8595 - val_loss: 0.3652 - learning_rate: 1.1065e-04
# Epoch 44/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - accuracy: 0.8372 - loss: 0.4142 - val_accuracy: 0.8578 - val_loss: 0.3635 - learning_rate: 1.0012e-04
# Epoch 45/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - accuracy: 0.8356 - loss: 0.4133 - val_accuracy: 0.8627 - val_loss: 0.3588 - learning_rate: 9.0592e-05
# Epoch 46/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 45s 7ms/step - accuracy: 0.8386 - loss: 0.4057 - val_accuracy: 0.8597 - val_loss: 0.3602 - learning_rate: 8.1971e-05
# Epoch 47/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8346 - loss: 0.4113 - val_accuracy: 0.8616 - val_loss: 0.3610 - learning_rate: 7.4171e-05
# Epoch 48/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 35s 5ms/step - accuracy: 0.8468 - loss: 0.4007 - val_accuracy: 0.8633 - val_loss: 0.3598 - learning_rate: 6.7112e-05
# Epoch 49/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - accuracy: 0.8377 - loss: 0.4085 - val_accuracy: 0.8617 - val_loss: 0.3582 - learning_rate: 6.0726e-05
# Epoch 50/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - accuracy: 0.8396 - loss: 0.4061 - val_accuracy: 0.8594 - val_loss: 0.3594 - learning_rate: 5.4947e-05
# Epoch 51/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.8393 - loss: 0.4061 - val_accuracy: 0.8593 - val_loss: 0.3616 - learning_rate: 4.9718e-05
# Epoch 52/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - accuracy: 0.8424 - loss: 0.3998 - val_accuracy: 0.8602 - val_loss: 0.3603 - learning_rate: 4.4987e-05
# Epoch 53/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 36s 5ms/step - accuracy: 0.8410 - loss: 0.4013 - val_accuracy: 0.8601 - val_loss: 0.3601 - learning_rate: 4.0706e-05
# Epoch 54/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 35s 5ms/step - accuracy: 0.8368 - loss: 0.4089 - val_accuracy: 0.8595 - val_loss: 0.3597 - learning_rate: 3.6832e-05
# Epoch 55/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - accuracy: 0.8428 - loss: 0.4054 - val_accuracy: 0.8595 - val_loss: 0.3607 - learning_rate: 3.3327e-05
# Epoch 56/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.8389 - loss: 0.4032 - val_accuracy: 0.8602 - val_loss: 0.3594 - learning_rate: 3.0156e-05
# Epoch 57/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 44s 7ms/step - accuracy: 0.8425 - loss: 0.4019 - val_accuracy: 0.8605 - val_loss: 0.3580 - learning_rate: 2.7286e-05
# Epoch 58/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 46s 7ms/step - accuracy: 0.8412 - loss: 0.4042 - val_accuracy: 0.8614 - val_loss: 0.3566 - learning_rate: 2.4689e-05
# Epoch 59/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 46s 7ms/step - accuracy: 0.8442 - loss: 0.3997 - val_accuracy: 0.8626 - val_loss: 0.3570 - learning_rate: 2.2340e-05
# Epoch 60/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - accuracy: 0.8433 - loss: 0.4003 - val_accuracy: 0.8607 - val_loss: 0.3567 - learning_rate: 2.0214e-05
# Epoch 61/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - accuracy: 0.8427 - loss: 0.4026 - val_accuracy: 0.8609 - val_loss: 0.3558 - learning_rate: 1.8290e-05
# Epoch 62/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 45s 7ms/step - accuracy: 0.8434 - loss: 0.3995 - val_accuracy: 0.8607 - val_loss: 0.3559 - learning_rate: 1.6550e-05
# Epoch 63/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - accuracy: 0.8424 - loss: 0.4044 - val_accuracy: 0.8595 - val_loss: 0.3575 - learning_rate: 1.4975e-05
# Epoch 64/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - accuracy: 0.8418 - loss: 0.3977 - val_accuracy: 0.8598 - val_loss: 0.3583 - learning_rate: 1.3550e-05
# Epoch 65/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - accuracy: 0.8458 - loss: 0.3971 - val_accuracy: 0.8608 - val_loss: 0.3565 - learning_rate: 1.2260e-05
# Epoch 66/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8458 - loss: 0.3972 - val_accuracy: 0.8597 - val_loss: 0.3607 - learning_rate: 1.1094e-05
# Epoch 67/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - accuracy: 0.8393 - loss: 0.4053 - val_accuracy: 0.8599 - val_loss: 0.3586 - learning_rate: 1.0038e-05
# Epoch 68/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 39s 6ms/step - accuracy: 0.8357 - loss: 0.4032 - val_accuracy: 0.8602 - val_loss: 0.3574 - learning_rate: 9.0827e-06
# Epoch 69/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 37s 5ms/step - accuracy: 0.8440 - loss: 0.4021 - val_accuracy: 0.8602 - val_loss: 0.3596 - learning_rate: 8.2183e-06
# Epoch 70/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - accuracy: 0.8414 - loss: 0.4026 - val_accuracy: 0.8596 - val_loss: 0.3579 - learning_rate: 7.4363e-06
# Epoch 71/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 40s 6ms/step - accuracy: 0.8406 - loss: 0.4005 - val_accuracy: 0.8605 - val_loss: 0.3576 - learning_rate: 6.7286e-06
# Epoch 72/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 47s 7ms/step - accuracy: 0.8427 - loss: 0.3969 - val_accuracy: 0.8606 - val_loss: 0.3558 - learning_rate: 6.0883e-06
# Epoch 73/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 49s 7ms/step - accuracy: 0.8464 - loss: 0.3936 - val_accuracy: 0.8603 - val_loss: 0.3582 - learning_rate: 5.5089e-06
# Epoch 74/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.8356 - loss: 0.4063 - val_accuracy: 0.8598 - val_loss: 0.3592 - learning_rate: 4.9847e-06
# Epoch 75/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.8411 - loss: 0.3980 - val_accuracy: 0.8597 - val_loss: 0.3580 - learning_rate: 4.5103e-06
# Epoch 76/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.8451 - loss: 0.3971 - val_accuracy: 0.8601 - val_loss: 0.3575 - learning_rate: 4.0811e-06
# Epoch 77/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 47s 7ms/step - accuracy: 0.8399 - loss: 0.3976 - val_accuracy: 0.8604 - val_loss: 0.3564 - learning_rate: 3.6927e-06
# Epoch 78/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 47s 7ms/step - accuracy: 0.8408 - loss: 0.4010 - val_accuracy: 0.8602 - val_loss: 0.3585 - learning_rate: 3.3413e-06
# Epoch 79/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step - accuracy: 0.8403 - loss: 0.3991 - val_accuracy: 0.8602 - val_loss: 0.3570 - learning_rate: 3.0234e-06
# Epoch 80/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 43s 6ms/step - accuracy: 0.8411 - loss: 0.4007 - val_accuracy: 0.8603 - val_loss: 0.3578 - learning_rate: 2.7356e-06
# Epoch 81/500
# 6791/6791 ━━━━━━━━━━━━━━━━━━━━ 46s 7ms/step - accuracy: 0.8429 - loss: 0.3991 - val_accuracy: 0.8604 - val_loss: 0.3569 - learning_rate: 2.4753e-06

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
plt.plot(training_record.history["loss"], label="Training Loss")
plt.plot(training_record.history["val_loss"], label="Validation Loss")
plt.legend()
fig.suptitle("Loss")
plt.show()

# %%
y_pred_probs = model.predict(X_test)
# Out:
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step

# %%
y_pred_probs
# Out:
# array([[0.5389904 ],
#        [0.85189116],
#        [0.9369719 ],
#        ...,
#        [0.00529191],
#        [0.7450854 ],
#        [0.30954406]], dtype=float32)

# %%
y_pred_probs[16631][0]
# Out:
# 0.30954406

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

y_pred = (y_pred_probs > 0.5).astype('int32')

# %%
y_pred
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [1],
#        [0]], dtype=int32)

# %%
y_test=np.array(y_test).astype('int32')

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc


fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(10, 8)) 
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)  
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=16)  
plt.ylabel('True Positive Rate', fontsize=16)  
plt.title('Receiver Operating Characteristic (ROC)', fontsize=18)  
plt.legend(loc="lower right", fontsize=14)  
plt.grid(True)  
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt


precision, recall, thresholds = precision_recall_curve(y_test, y_pred_probs)


average_precision = average_precision_score(y_test, y_pred_probs)

plt.figure(figsize=(8, 6))  
plt.plot(recall, precision, label='PRC curve (AP = {:.2f})'.format(average_precision), linewidth=2, color='blue')  
plt.xlabel('Recall', fontsize=14)  
plt.ylabel('Precision', fontsize=14)  
plt.title('Precision-Recall Curve', fontsize=16)  
plt.legend(loc="lower left", fontsize=12)  
plt.grid(True)  
plt.xlim([0.0, 1.0])  
plt.ylim([0.0, 1.05])  
plt.show()

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy_score: {accuracy}')
# Out:
# accuracy_score: 0.8621332371332371

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print('confusion matrix:')
print(conf_matrix)
# Out:
# confusion matrix:
# [[6830 1448]
#  [ 845 7509]]

# %%
class_report = classification_report(y_test, y_pred, target_names=['Class 0', 'Class 1'])
print('classification_report')
print(class_report)
# Out:
# classification_report
#               precision    recall  f1-score   support
#
#      Class 0       0.89      0.83      0.86      8278
#      Class 1       0.84      0.90      0.87      8354
#
#     accuracy                           0.86     16632
#    macro avg       0.86      0.86      0.86     16632
# weighted avg       0.86      0.86      0.86     16632

# %%
model.save('voice detection model 0715(1).keras')

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Layer, Dense, MultiHeadAttention, LayerNormalization
import numpy as np

# 사용자 정의 TransformerBlock 레이어 정의
class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, **kwargs):
        super(TransformerBlock, self).__init__(**kwargs)
        self.att = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential(
            [Dense(ff_dim, activation="relu"), Dense(embed_dim),]
        )
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)

    def call(self, inputs, training=False):
        attn_output = self.att(inputs, inputs)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        return self.layernorm2(out1 + ffn_output)

# %%
# 모델 경로
model_path = '/Users/withmocha/Desktop/visual studio code/SW_DACON(24)/model/0714/best_model.keras'  # 저장된 모델 파일 경로

# 저장된 모델 불러오기
loaded_model = load_model(model_path, custom_objects={'TransformerBlock': TransformerBlock})

# 모델 요약 출력
loaded_model.summary()
# Out:
# /opt/anaconda3/envs/conda_cpu/lib/python3.12/site-packages/keras/src/layers/layer.py:361: UserWarning: `build()` was called on layer 'transformer_block', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 1016, 1)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 1012, 64)  │        384 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 1012, 64)  │          0 │ conv1d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 1008, 32)  │     10,272 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 1016, 64)  │      8,704 │ input_layer_2[0]… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 1008, 32)  │          0 │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 1016, 64)  │          0 │ bidirectional_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 1004, 16)  │      2,576 │ dropout_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_4     │ (None, 1016, 32)  │     10,368 │ dropout_9[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 502, 16)   │          0 │ conv1d_5[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 1016, 32)  │          0 │ bidirectional_4[… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_block   │ (None, 1016, 1)   │        130 │ input_layer_2[0]… │
# │ (TransformerBlock)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 8032)      │          0 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_5     │ (None, 16)        │      2,624 │ dropout_10[0][0]  │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 1016)      │          0 │ transformer_bloc… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 9064)      │          0 │ flatten_2[0][0],  │
# │ (Concatenate)       │                   │            │ bidirectional_5[… │
# │                     │                   │            │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 16)        │    145,040 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 16)        │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 8)         │        136 │ dropout_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 8)         │          0 │ dense_8[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1)         │          9 │ dropout_13[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 540,731 (2.06 MB)
#  Trainable params: 180,243 (704.07 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 360,488 (1.38 MB)

# %%
y_pred_probs = model.predict(X_test)
# Out:
# 520/520 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step

# %%
y_pred = (y_pred_probs > 0.5).astype('int32')

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy_score: {accuracy}')
# Out:
# accuracy_score: 0.8621332371332371
