# %%
import pandas as pd 

process1_train_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/final/process1/NLP/L12/train/process1 train data after nlp(L12).csv")
process1_test_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/final/process1/NLP/L12/test/process1 test data after nlp(L12).csv")

# %%
process1_train_row
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0           2130  0.052681  0.053340  0.049926  0.050476 -0.025834 -0.075918
# 1           1973  0.038633  0.117251  0.036907  0.035491 -0.001167 -0.061041
# 2           2682  0.059164  0.117286  0.061836  0.014222  0.015387 -0.106569
# 3           1500  0.079580  0.104174  0.083929  0.015054 -0.004028 -0.059743
# 4            863  0.122123  0.109663  0.074790  0.045607 -0.002871 -0.122592
# ...          ...       ...       ...       ...       ...       ...       ...
# 3527        1443 -0.020560  0.114968  0.090542  0.037182 -0.033965 -0.073257
# 3528        1819  0.005473  0.107869  0.017736  0.006528  0.003590 -0.080791
# 3529        3039 -0.033943  0.062056  0.027151 -0.007793  0.004635 -0.118097
# 3530        3290  0.120380  0.153412  0.088795  0.063998 -0.032955 -0.108393
# 3531        1124  0.055092  0.107332  0.080639  0.054500  0.007977 -0.091331
#
#              6         7         8  ...       375       376       377  \
# 0     0.070980 -0.000335 -0.060250  ...  0.013799  0.007726  0.015177
# 1     0.075565  0.006134 -0.073180  ... -0.080753 -0.007517  0.038763
# 2     0.063511 -0.053788 -0.069483  ... -0.051480 -0.015387 -0.004514
# 3     0.088963  0.023656 -0.080602  ...  0.067732  0.052790  0.089213
# 4     0.081832  0.003311 -0.023709  ...  0.000983  0.016179  0.072141
# ...        ...       ...       ...  ...       ...       ...       ...
# 3527  0.082439 -0.042006 -0.111205  ...  0.035063 -0.009005  0.001712
# 3528  0.095931 -0.046186 -0.086261  ...  0.037513  0.040081 -0.007233
# 3529  0.084947 -0.069223 -0.058607  ...  0.031206  0.008606  0.008056
# 3530  0.082552  0.025520 -0.063058  ...  0.038962  0.039133  0.052265
# 3531  0.128289 -0.002353 -0.062055  ...  0.062528  0.036488  0.048164
#
#            378       379       380       381       382       383  predict
# 0    -0.013155  0.069447  0.024753  0.038063 -0.080425 -0.009171        0
# 1     0.028846  0.025833 -0.019822  0.069651 -0.024857 -0.006459        0
# 2    -0.004432  0.022741 -0.014364  0.117365 -0.052121 -0.022244        0
# 3     0.013857  0.058137 -0.002398  0.093943 -0.038643  0.034060        1
# 4    -0.033758  0.049317  0.042181  0.032310 -0.049460  0.015013        1
# ...        ...       ...       ...       ...       ...       ...      ...
# 3527 -0.001025  0.006916 -0.042048  0.056844 -0.002090  0.003419        0
# 3528  0.011960  0.062608 -0.018076  0.068869 -0.078631 -0.024864        0
# 3529 -0.032903  0.025994 -0.041332  0.027292 -0.057206 -0.037201        0
# 3530 -0.042251  0.064331  0.038921  0.069663 -0.047869  0.027860        1
# 3531  0.015712  0.034549 -0.065234  0.037178 -0.037414 -0.012771        0
#
# [3532 rows x 386 columns]

# %%
process1_test_row
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0           211 -0.041206  0.068625  0.068453 -0.018952  0.024623 -0.040077
# 1           271  0.024179 -0.013447  0.072466  0.023402 -0.001705 -0.076872
# 2           251  0.053661  0.007048  0.055320  0.000168 -0.019227 -0.042684
# 3            44 -0.025268  0.031403  0.098619 -0.033901 -0.044453 -0.032371
# 4           210 -0.014361  0.083844  0.105518  0.006905 -0.014392 -0.050227
# ..          ...       ...       ...       ...       ...       ...       ...
# 295          95  0.017671  0.027869  0.029987 -0.006337 -0.058718 -0.041600
# 296          21  0.009776  0.060774  0.072311 -0.032546  0.027267 -0.030231
# 297         239  0.002581  0.069615  0.073802 -0.033874 -0.039886 -0.017510
# 298          22 -0.005001  0.027463  0.067711  0.001685 -0.015014 -0.049089
# 299          35  0.055123  0.082150  0.028069 -0.049235 -0.012878 -0.081961
#
#             6         7         8  ...       375       376       377  \
# 0    0.076370 -0.009835 -0.032692  ...  0.017020  0.021544  0.056168
# 1    0.035353  0.051986  0.012902  ...  0.013969 -0.005540  0.065035
# 2    0.003062  0.057084 -0.042769  ...  0.039435 -0.010071  0.020271
# 3    0.125864 -0.010151 -0.006881  ...  0.019225 -0.017981  0.010251
# 4    0.098413  0.026913 -0.063458  ...  0.052269 -0.007599  0.043497
# ..        ...       ...       ...  ...       ...       ...       ...
# 295  0.047350  0.043062 -0.022818  ... -0.019619 -0.049474 -0.002966
# 296  0.045242  0.048363 -0.037525  ... -0.018536 -0.010069  0.040010
# 297  0.174993 -0.007599 -0.025805  ...  0.042294 -0.018132  0.018385
# 298  0.026421  0.007331 -0.008847  ...  0.023919 -0.028119  0.095122
# 299  0.063570  0.065327 -0.019936  ...  0.045961 -0.046246  0.016818
#
#           378       379       380       381       382       383  predict
# 0    0.019053 -0.016004  0.061347  0.041876 -0.043895 -0.049710        1
# 1   -0.018843 -0.036418  0.048326  0.047785 -0.045155  0.026087        1
# 2   -0.019725 -0.016525  0.038851  0.014915 -0.045939  0.019709        1
# 3    0.049546 -0.002956  0.060103  0.100662 -0.110234 -0.083568        0
# 4    0.010305 -0.021516  0.091189  0.099985 -0.136647 -0.057376        0
# ..        ...       ...       ...       ...       ...       ...      ...
# 295 -0.002810  0.031547 -0.026341 -0.017630 -0.041253 -0.035566        1
# 296 -0.014769  0.036100  0.019309  0.006928 -0.027482 -0.018435        1
# 297 -0.016370  0.018908  0.095877  0.094576 -0.063031 -0.063957        0
# 298  0.044609  0.004182  0.059505 -0.002236 -0.055606 -0.030844        1
# 299  0.036221 -0.027889  0.014602 -0.004710 -0.088208  0.002718        0
#
# [300 rows x 386 columns]

# %%
process1_x_train=process1_train_row
process1_x_train=process1_x_train.drop(columns=['predict'])
process1_x_train=process1_x_train.drop(columns=['Unnamed: 0'])
process1_y_train=pd.DataFrame(process1_train_row['predict'])

# %%
process1_x_train
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.052681  0.053340  0.049926  0.050476 -0.025834 -0.075918  0.070980
# 1     0.038633  0.117251  0.036907  0.035491 -0.001167 -0.061041  0.075565
# 2     0.059164  0.117286  0.061836  0.014222  0.015387 -0.106569  0.063511
# 3     0.079580  0.104174  0.083929  0.015054 -0.004028 -0.059743  0.088963
# 4     0.122123  0.109663  0.074790  0.045607 -0.002871 -0.122592  0.081832
# ...        ...       ...       ...       ...       ...       ...       ...
# 3527 -0.020560  0.114968  0.090542  0.037182 -0.033965 -0.073257  0.082439
# 3528  0.005473  0.107869  0.017736  0.006528  0.003590 -0.080791  0.095931
# 3529 -0.033943  0.062056  0.027151 -0.007793  0.004635 -0.118097  0.084947
# 3530  0.120380  0.153412  0.088795  0.063998 -0.032955 -0.108393  0.082552
# 3531  0.055092  0.107332  0.080639  0.054500  0.007977 -0.091331  0.128289
#
#              7         8         9  ...       374       375       376  \
# 0    -0.000335 -0.060250 -0.022353  ...  0.049138  0.013799  0.007726
# 1     0.006134 -0.073180 -0.056844  ... -0.005421 -0.080753 -0.007517
# 2    -0.053788 -0.069483 -0.118864  ...  0.014637 -0.051480 -0.015387
# 3     0.023656 -0.080602 -0.007944  ...  0.057267  0.067732  0.052790
# 4     0.003311 -0.023709 -0.076324  ...  0.028558  0.000983  0.016179
# ...        ...       ...       ...  ...       ...       ...       ...
# 3527 -0.042006 -0.111205 -0.049645  ...  0.045594  0.035063 -0.009005
# 3528 -0.046186 -0.086261 -0.014261  ...  0.040952  0.037513  0.040081
# 3529 -0.069223 -0.058607 -0.056586  ...  0.014678  0.031206  0.008606
# 3530  0.025520 -0.063058 -0.089014  ...  0.072145  0.038962  0.039133
# 3531 -0.002353 -0.062055 -0.047511  ...  0.026496  0.062528  0.036488
#
#            377       378       379       380       381       382       383
# 0     0.015177 -0.013155  0.069447  0.024753  0.038063 -0.080425 -0.009171
# 1     0.038763  0.028846  0.025833 -0.019822  0.069651 -0.024857 -0.006459
# 2    -0.004514 -0.004432  0.022741 -0.014364  0.117365 -0.052121 -0.022244
# 3     0.089213  0.013857  0.058137 -0.002398  0.093943 -0.038643  0.034060
# 4     0.072141 -0.033758  0.049317  0.042181  0.032310 -0.049460  0.015013
# ...        ...       ...       ...       ...       ...       ...       ...
# 3527  0.001712 -0.001025  0.006916 -0.042048  0.056844 -0.002090  0.003419
# 3528 -0.007233  0.011960  0.062608 -0.018076  0.068869 -0.078631 -0.024864
# 3529  0.008056 -0.032903  0.025994 -0.041332  0.027292 -0.057206 -0.037201
# 3530  0.052265 -0.042251  0.064331  0.038921  0.069663 -0.047869  0.027860
# 3531  0.048164  0.015712  0.034549 -0.065234  0.037178 -0.037414 -0.012771
#
# [3532 rows x 384 columns]

# %%
process1_y_train
# Out:
#       predict
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# ...       ...
# 3527        0
# 3528        0
# 3529        0
# 3530        1
# 3531        0
#
# [3532 rows x 1 columns]

# %%
process1_x_test=process1_test_row
process1_x_test=process1_x_test.drop(columns=['predict'])
process1_x_test=process1_x_test.drop(columns=['Unnamed: 0'])
process1_y_test=pd.DataFrame(process1_test_row['predict'])

# %%
process1_x_test
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.041206  0.068625  0.068453 -0.018952  0.024623 -0.040077  0.076370
# 1    0.024179 -0.013447  0.072466  0.023402 -0.001705 -0.076872  0.035353
# 2    0.053661  0.007048  0.055320  0.000168 -0.019227 -0.042684  0.003062
# 3   -0.025268  0.031403  0.098619 -0.033901 -0.044453 -0.032371  0.125864
# 4   -0.014361  0.083844  0.105518  0.006905 -0.014392 -0.050227  0.098413
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.017671  0.027869  0.029987 -0.006337 -0.058718 -0.041600  0.047350
# 296  0.009776  0.060774  0.072311 -0.032546  0.027267 -0.030231  0.045242
# 297  0.002581  0.069615  0.073802 -0.033874 -0.039886 -0.017510  0.174993
# 298 -0.005001  0.027463  0.067711  0.001685 -0.015014 -0.049089  0.026421
# 299  0.055123  0.082150  0.028069 -0.049235 -0.012878 -0.081961  0.063570
#
#             7         8         9  ...       374       375       376  \
# 0   -0.009835 -0.032692 -0.037372  ... -0.023998  0.017020  0.021544
# 1    0.051986  0.012902 -0.040045  ... -0.076038  0.013969 -0.005540
# 2    0.057084 -0.042769 -0.023711  ... -0.052824  0.039435 -0.010071
# 3   -0.010151 -0.006881 -0.003483  ...  0.034184  0.019225 -0.017981
# 4    0.026913 -0.063458  0.001598  ...  0.017561  0.052269 -0.007599
# ..        ...       ...       ...  ...       ...       ...       ...
# 295  0.043062 -0.022818 -0.052122  ... -0.057832 -0.019619 -0.049474
# 296  0.048363 -0.037525 -0.056925  ... -0.012809 -0.018536 -0.010069
# 297 -0.007599 -0.025805 -0.024437  ...  0.038944  0.042294 -0.018132
# 298  0.007331 -0.008847 -0.043589  ... -0.042129  0.023919 -0.028119
# 299  0.065327 -0.019936  0.005274  ...  0.046217  0.045961 -0.046246
#
#           377       378       379       380       381       382       383
# 0    0.056168  0.019053 -0.016004  0.061347  0.041876 -0.043895 -0.049710
# 1    0.065035 -0.018843 -0.036418  0.048326  0.047785 -0.045155  0.026087
# 2    0.020271 -0.019725 -0.016525  0.038851  0.014915 -0.045939  0.019709
# 3    0.010251  0.049546 -0.002956  0.060103  0.100662 -0.110234 -0.083568
# 4    0.043497  0.010305 -0.021516  0.091189  0.099985 -0.136647 -0.057376
# ..        ...       ...       ...       ...       ...       ...       ...
# 295 -0.002966 -0.002810  0.031547 -0.026341 -0.017630 -0.041253 -0.035566
# 296  0.040010 -0.014769  0.036100  0.019309  0.006928 -0.027482 -0.018435
# 297  0.018385 -0.016370  0.018908  0.095877  0.094576 -0.063031 -0.063957
# 298  0.095122  0.044609  0.004182  0.059505 -0.002236 -0.055606 -0.030844
# 299  0.016818  0.036221 -0.027889  0.014602 -0.004710 -0.088208  0.002718
#
# [300 rows x 384 columns]

# %%
process1_y_test
# Out:
#      predict
# 0          1
# 1          1
# 2          1
# 3          0
# 4          0
# ..       ...
# 295        1
# 296        1
# 297        0
# 298        1
# 299        0
#
# [300 rows x 1 columns]

# %%
print(process1_x_train.shape)
print(process1_y_train.shape)
print(process1_x_test.shape)
print(process1_y_test.shape)
# Out:
# (3532, 384)
# (3532, 1)
# (300, 384)
# (300, 1)

# %%
import tensorflow as tf

x_train = tf.reshape(process1_x_train,(process1_x_train.shape[0],process1_x_train.shape[1],1))
test_x = tf.reshape(process1_x_test,(process1_x_test.shape[0],process1_x_test.shape[1],1))

# %%
print(x_train.shape)
print(process1_y_train.shape)
print(test_x.shape)
print(process1_y_test.shape)
# Out:
# (3532, 384, 1)
# (3532, 1)
# (300, 384, 1)
# (300, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional, Conv1D, MaxPooling1D, Flatten,ELU,Permute
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler
import tensorflow as tf
from tensorflow.keras.activations import elu


def lr_schedule(epoch, lr):
    if epoch > 5:
        return float(lr * tf.math.exp(-0.1))  
    return float(lr)  

fishing_detection_model = tf.keras.Sequential()

fishing_detection_model.add(Conv1D(filters=512, kernel_size=3, input_shape=(x_train.shape[1], x_train.shape[2]), padding='same'))
fishing_detection_model.add(ELU())

fishing_detection_model.add(Conv1D(filters=256, kernel_size=3, padding='same'))
fishing_detection_model.add(ELU())

fishing_detection_model.add(MaxPooling1D(pool_size=2))

fishing_detection_model.add(Conv1D(filters=128, kernel_size=3, padding='same'))
fishing_detection_model.add(ELU())

fishing_detection_model.add(Conv1D(filters=64, kernel_size=3, padding='same'))
fishing_detection_model.add(ELU())

fishing_detection_model.add(MaxPooling1D(pool_size=2))

fishing_detection_model.add(Dropout(0.5))


fishing_detection_model.add(Permute((2, 1)))


fishing_detection_model.add(Bidirectional(LSTM(512, return_sequences=True)))
fishing_detection_model.add(Bidirectional(LSTM(256, return_sequences=True)))
fishing_detection_model.add(Bidirectional(LSTM(128, return_sequences=False)))

fishing_detection_model.add(Dropout(0.5))

fishing_detection_model.add(Dense(64))
fishing_detection_model.add(ELU())

fishing_detection_model.add(Dropout(0.5))

fishing_detection_model.add(Dense(1, activation='sigmoid'))

fishing_detection_model.compile(optimizer=tf.keras.optimizers.Adamax(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])


early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_fishing_detection_model.keras', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)

fishing_detection_model.summary()
# Out:
# /opt/anaconda3/envs/conda_cpu/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_12 (Conv1D)              │ (None, 384, 512)       │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_15 (ELU)                    │ (None, 384, 512)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_13 (Conv1D)              │ (None, 384, 256)       │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_16 (ELU)                    │ (None, 384, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 192, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_14 (Conv1D)              │ (None, 192, 128)       │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_17 (ELU)                    │ (None, 192, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_15 (Conv1D)              │ (None, 192, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_18 (ELU)                    │ (None, 192, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 96, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 96, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute_3 (Permute)             │ (None, 64, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_9 (Bidirectional) │ (None, 64, 1024)       │     2,494,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_10                │ (None, 64, 512)        │     2,623,488 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_11                │ (None, 256)            │       656,384 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_19 (ELU)                    │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,309,441 (24.07 MB)
#  Trainable params: 6,309,441 (24.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
training_record = fishing_detection_model.fit(x_train, process1_y_train,
                    epochs=15,
                    batch_size=32,
                    callbacks=[early_stopping, model_checkpoint,lr_scheduler],
                    validation_split=0.3,
                    shuffle=True)
# Out:
# Epoch 1/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 493ms/step - accuracy: 0.7543 - loss: 0.4305 - val_accuracy: 0.9745 - val_loss: 0.0850 - learning_rate: 0.0010
# Epoch 2/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 48s 614ms/step - accuracy: 0.9717 - loss: 0.0867 - val_accuracy: 0.9642 - val_loss: 0.1052 - learning_rate: 0.0010
# Epoch 3/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 72s 929ms/step - accuracy: 0.9835 - loss: 0.0567 - val_accuracy: 0.9792 - val_loss: 0.0715 - learning_rate: 0.0010
# Epoch 4/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 74s 946ms/step - accuracy: 0.9770 - loss: 0.0723 - val_accuracy: 0.9849 - val_loss: 0.0590 - learning_rate: 0.0010
# Epoch 5/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 64s 827ms/step - accuracy: 0.9845 - loss: 0.0449 - val_accuracy: 0.9849 - val_loss: 0.0532 - learning_rate: 0.0010
# Epoch 6/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 71s 905ms/step - accuracy: 0.9828 - loss: 0.0485 - val_accuracy: 0.9802 - val_loss: 0.0634 - learning_rate: 0.0010
# Epoch 7/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 74s 948ms/step - accuracy: 0.9846 - loss: 0.0403 - val_accuracy: 0.9830 - val_loss: 0.0501 - learning_rate: 9.0484e-04
# Epoch 8/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 76s 982ms/step - accuracy: 0.9917 - loss: 0.0323 - val_accuracy: 0.9858 - val_loss: 0.0528 - learning_rate: 8.1873e-04
# Epoch 9/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 77s 990ms/step - accuracy: 0.9943 - loss: 0.0219 - val_accuracy: 0.9792 - val_loss: 0.0627 - learning_rate: 7.4082e-04
# Epoch 10/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 59s 758ms/step - accuracy: 0.9878 - loss: 0.0340 - val_accuracy: 0.9849 - val_loss: 0.0526 - learning_rate: 6.7032e-04
# Epoch 11/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 45s 576ms/step - accuracy: 0.9931 - loss: 0.0189 - val_accuracy: 0.9849 - val_loss: 0.0460 - learning_rate: 6.0653e-04
# Epoch 12/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 532ms/step - accuracy: 0.9945 - loss: 0.0148 - val_accuracy: 0.9774 - val_loss: 0.0937 - learning_rate: 5.4881e-04
# Epoch 13/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 520ms/step - accuracy: 0.9934 - loss: 0.0292 - val_accuracy: 0.9821 - val_loss: 0.0600 - learning_rate: 4.9659e-04
# Epoch 14/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 44s 569ms/step - accuracy: 0.9972 - loss: 0.0127 - val_accuracy: 0.9849 - val_loss: 0.0568 - learning_rate: 4.4933e-04
# Epoch 15/15
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 41s 520ms/step - accuracy: 0.9940 - loss: 0.0191 - val_accuracy: 0.9840 - val_loss: 0.0648 - learning_rate: 4.0657e-04

# %%
fishing_detection_model.save('fishing_detection_model(L12).keras')

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8, 6))
plt.plot(training_record.history['loss'], label='train loss')
plt.plot(training_record.history['val_loss'], label='val loss')
plt.title('train and val loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
y_pred = fishing_detection_model.predict(test_x).ravel()
fpr, tpr, thresholds = roc_curve(process1_y_test, y_pred)
auc_value = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_value:.2f}')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step

# %%
precision, recall, _ = precision_recall_curve(process1_y_test, y_pred)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='precision-recall curve')
plt.title('PRC Curve')
plt.xlabel('Recall')
plt.ylabel('Precisio')
plt.legend(loc='lower left')
plt.show()

# %%
y_pred_binary = np.where(y_pred > 0.5, 1, 0)  
accuracy = accuracy_score(process1_y_test, y_pred_binary)
print(f'accuracy score: {accuracy:.2f}')
# Out:
# accuracy score: 0.74

# %%
cm = confusion_matrix(process1_y_test, y_pred_binary)
fig, ax = plt.subplots(figsize=(6, 6))
cax = ax.matshow(cm, cmap=plt.cm.Blues)
fig.colorbar(cax)
plt.title('confusion matrix')
plt.xlabel('prediction value')
plt.ylabel('real value')
plt.xticks([0, 1], ['0', '1'])
plt.yticks([0, 1], ['0', '1'])
for (i, j), val in np.ndenumerate(cm):
    ax.text(j, i, f'{val}', ha='center', va='center')
plt.show()

# %%
print(classification_report(process1_y_test, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.59      0.70       155
#            1       0.68      0.90      0.77       145
#
#     accuracy                           0.74       300
#    macro avg       0.77      0.75      0.74       300
# weighted avg       0.77      0.74      0.74       300
