# 0    -0.015657  0.005886 -0.022612  ... -0.016425 -0.023135 -0.018216
# 1     0.021183  0.066210 -0.029791  ...  0.016895 -0.002364  0.005712
# 2    -0.005508  0.059626  0.006950  ... -0.010666 -0.009995 -0.015583
# 3    -0.003118  0.057112  0.003470  ... -0.022584 -0.021698 -0.028114
# 4     0.012209  0.040403 -0.005309  ... -0.059021 -0.004835 -0.032909
# ...        ...       ...       ...  ...       ...       ...       ...
# 1527 -0.003860  0.062821  0.016533  ... -0.027407  0.004696  0.029834
# 1528  0.003832  0.013537 -0.028860  ...  0.009003 -0.011484 -0.014344
# 1529 -0.007677  0.055978  0.004680  ... -0.030697 -0.026276 -0.031089
# 1530  0.006264  0.063067  0.002875  ... -0.005176  0.002667 -0.003834
# 1531  0.012987  0.045415 -0.001501  ... -0.013572 -0.020254 -0.026486
#
#            761       762       763       764       765       766       767
# 0     0.005023 -0.040850 -0.028039  0.039825  0.012674  0.001627 -0.045246
# 1     0.028058 -0.039960 -0.051352 -0.011591  0.035369  0.018552 -0.015690
# 2    -0.000062 -0.043795 -0.029255  0.019135  0.046351  0.016176 -0.045390
# 3     0.010806 -0.036559 -0.042335  0.027408  0.036842  0.003416 -0.038260
# 4    -0.018467 -0.040125 -0.044182  0.010288 -0.010474  0.001798 -0.037051
# ...        ...       ...       ...       ...       ...       ...       ...
# 1527 -0.020498 -0.045387 -0.051133  0.009698  0.022053 -0.002892 -0.043821
# 1528  0.022870 -0.045492 -0.029669  0.000854  0.030269  0.009566 -0.014869
# 1529  0.001846 -0.033731 -0.045328  0.028230  0.020006  0.012729 -0.033355
# 1530  0.006973 -0.045958 -0.031906  0.020211  0.021819  0.021288 -0.049615
# 1531  0.018867 -0.008987 -0.013603  0.046720  0.021596  0.000012 -0.033974
#
# [1532 rows x 768 columns]

# %%
process2_y_train
# Out:
#       predict
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1
# ...       ...
# 1527        1
# 1528        0
# 1529        1
# 1530        1
# 1531        0
#
# [1532 rows x 1 columns]

# %%
process2_x_test=process2_test_row
process2_x_test=process2_x_test.drop(columns=['predict'])
process2_x_test=process2_x_test.drop(columns=['Unnamed: 0'])
process2_y_test=pd.DataFrame(process2_test_row['predict'])

# %%
process2_x_test
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.079496 -0.034961 -0.034037  0.025270  0.016199  0.009175 -0.023156
# 1    0.066897 -0.026018 -0.032159  0.054091  0.023909  0.004876 -0.040261
# 2    0.022137 -0.009706 -0.036984  0.007890  0.016075 -0.018909  0.001039
# 3    0.083911 -0.016560 -0.041840  0.010965 -0.005164 -0.001851  0.012788
# 4    0.096724 -0.044900 -0.036691  0.035524  0.005197  0.008395 -0.019607
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.058337 -0.030781 -0.018152 -0.003226  0.017410  0.015512  0.016240
# 296  0.064980  0.027805 -0.024346  0.013729  0.021370  0.003455 -0.027731
# 297  0.093785 -0.054416 -0.026962  0.001162  0.007890 -0.002255 -0.025937
# 298  0.064475 -0.006748 -0.038864 -0.009890 -0.010541 -0.003191 -0.005304
# 299  0.070042  0.031049 -0.035930  0.003945  0.009258  0.002141 -0.001078
#
#             7         8         9  ...       758       759       760  \
# 0    0.018706  0.070304 -0.004423  ...  0.000589  0.004128  0.002876
# 1    0.004242  0.088258  0.002097  ...  0.015542  0.000298  0.046956
# 2    0.007867  0.018826 -0.020290  ... -0.033601 -0.010175 -0.012739
# 3    0.016730  0.062876  0.011212  ... -0.009251 -0.022856 -0.029330
# 4    0.038883  0.086355 -0.000771  ...  0.001454 -0.011773 -0.010748
# ..        ...       ...       ...  ...       ...       ...       ...
# 295 -0.003289  0.049099  0.033109  ... -0.013244 -0.037080 -0.009304
# 296  0.014460  0.016309 -0.000148  ... -0.043076 -0.029784  0.004025
# 297  0.043801  0.031087 -0.035176  ... -0.014705  0.003785 -0.012906
# 298  0.023042  0.053992 -0.020232  ... -0.006190 -0.024202 -0.043829
# 299  0.023876  0.048743  0.008657  ...  0.018550 -0.047765 -0.039683
#
#           761       762       763       764       765       766       767
# 0    0.001546 -0.043530 -0.031774  0.010756  0.046584  0.010570 -0.032330
# 1    0.000438 -0.046043 -0.034888 -0.025774  0.038249  0.004057 -0.038578
# 2    0.026898 -0.001878 -0.013115  0.049147  0.031826 -0.039392 -0.040666
# 3    0.009009 -0.013251  0.008487  0.043772  0.031539  0.001517 -0.045872
# 4    0.004978 -0.029230  0.004834 -0.006439  0.021409  0.003470 -0.009113
# ..        ...       ...       ...       ...       ...       ...       ...
# 295 -0.017687 -0.030482 -0.003620  0.026901  0.032953 -0.003293 -0.053234
# 296  0.004650 -0.031063 -0.043745  0.053807  0.046206  0.002203 -0.046273
# 297  0.006502 -0.017480 -0.073413  0.026115  0.023523 -0.007057 -0.011876
# 298  0.023649 -0.030973 -0.044519  0.034897  0.044465  0.018212 -0.031688
# 299  0.016311 -0.021531 -0.017532  0.033711 -0.010529  0.013496 -0.018799
#
# [300 rows x 768 columns]

# %%
process2_y_test
# Out:
#      predict
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# ..       ...
# 295        0
# 296        1
# 297        1
# 298        1
# 299        1
#
# [300 rows x 1 columns]

# %%
print(process2_x_train.shape)
print(process2_y_train.shape)
print(process2_x_test.shape)
print(process2_y_test.shape)
# Out:
# (1532, 768)
# (1532, 1)
# (300, 768)
# (300, 1)

# %%
import tensorflow as tf

x_train = tf.reshape(process2_x_train,(process2_x_train.shape[0],process2_x_train.shape[1],1))
test_x = tf.reshape(process2_x_test,(process2_x_test.shape[0],process2_x_test.shape[1],1))
# Out:
# 2024-05-29 00:22:05.955527: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-05-29 00:22:05.955550: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2024-05-29 00:22:05.955555: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2024-05-29 00:22:05.955589: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-05-29 00:22:05.955600: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
print(x_train.shape)
print(process2_y_train.shape)
print(test_x.shape)
print(process2_y_test.shape)
# Out:
# (1532, 768, 1)
# (1532, 1)
# (300, 768, 1)
# (300, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional, Conv1D, MaxPooling1D, Flatten, GRU, ELU, Permute
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.regularizers import l2
import tensorflow as tf



fishing_classification_model = Sequential()

fishing_classification_model.add(Conv1D(filters=256, kernel_size=1, input_shape=(x_train.shape[1], x_train.shape[2])))
fishing_classification_model.add(ELU())

fishing_classification_model.add(Conv1D(filters=128, kernel_size=1))
fishing_classification_model.add(ELU())

fishing_classification_model.add(Conv1D(filters=64, kernel_size=1))
fishing_classification_model.add(ELU())

fishing_classification_model.add(MaxPooling1D(pool_size=1))

fishing_classification_model.add(Dropout(0.5))


fishing_classification_model.add(Permute((2, 1)))

fishing_classification_model.add(Bidirectional(LSTM(256, return_sequences=True)))
fishing_classification_model.add(Bidirectional(LSTM(128, return_sequences=False)))

fishing_classification_model.add(Dropout(0.5))

fishing_classification_model.add(Dense(32))
fishing_classification_model.add(ELU())

fishing_classification_model.add(Dropout(0.5))

fishing_classification_model.add(Dense(1, activation='sigmoid'))

fishing_classification_model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_fishing_classification_model_simplified.keras', save_best_only=True)

fishing_classification_model.summary()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 768, 256)       │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu (ELU)                       │ (None, 768, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 768, 128)       │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_1 (ELU)                     │ (None, 768, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 768, 64)        │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_2 (ELU)                     │ (None, 768, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 768, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 768, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute (Permute)               │ (None, 64, 768)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 64, 512)        │     2,099,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 256)            │       656,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         8,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_3 (ELU)                     │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,805,505 (10.70 MB)
#  Trainable params: 2,805,505 (10.70 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
training_record = fishing_classification_model.fit(x_train, process2_y_train,
                    epochs=25,
                    batch_size=10,
                    callbacks=[early_stopping, model_checkpoint],
                    validation_split=0.3,
                    shuffle=True)
# Out:
# Epoch 1/25
# 2024-05-29 00:22:07.583544: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 30s 219ms/step - accuracy: 0.6890 - loss: 0.6102 - val_accuracy: 0.7739 - val_loss: 0.4316
# Epoch 2/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - accuracy: 0.8046 - loss: 0.4680 - val_accuracy: 0.8587 - val_loss: 0.3169
# Epoch 3/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 148ms/step - accuracy: 0.8657 - loss: 0.3249 - val_accuracy: 0.7652 - val_loss: 0.5484
# Epoch 4/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 149ms/step - accuracy: 0.8818 - loss: 0.3220 - val_accuracy: 0.8609 - val_loss: 0.3335
# Epoch 5/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 147ms/step - accuracy: 0.8378 - loss: 0.3675 - val_accuracy: 0.8630 - val_loss: 0.2730
# Epoch 6/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 148ms/step - accuracy: 0.8835 - loss: 0.2721 - val_accuracy: 0.8804 - val_loss: 0.2653
# Epoch 7/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 16s 150ms/step - accuracy: 0.8687 - loss: 0.3033 - val_accuracy: 0.8891 - val_loss: 0.2613
# Epoch 8/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 169ms/step - accuracy: 0.8940 - loss: 0.2322 - val_accuracy: 0.9065 - val_loss: 0.2067
# Epoch 9/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 174ms/step - accuracy: 0.9083 - loss: 0.2112 - val_accuracy: 0.9239 - val_loss: 0.1916
# Epoch 10/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 172ms/step - accuracy: 0.9245 - loss: 0.2080 - val_accuracy: 0.8891 - val_loss: 0.2421
# Epoch 11/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 193ms/step - accuracy: 0.9258 - loss: 0.2098 - val_accuracy: 0.9000 - val_loss: 0.2297
# Epoch 12/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.9185 - loss: 0.1998 - val_accuracy: 0.8739 - val_loss: 0.2436
# Epoch 13/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - accuracy: 0.9022 - loss: 0.2401 - val_accuracy: 0.9109 - val_loss: 0.1939
# Epoch 14/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.9448 - loss: 0.1496 - val_accuracy: 0.9000 - val_loss: 0.2075
# Epoch 15/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9272 - loss: 0.1740 - val_accuracy: 0.9326 - val_loss: 0.1981
# Epoch 16/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 187ms/step - accuracy: 0.8940 - loss: 0.2525 - val_accuracy: 0.9043 - val_loss: 0.3329
# Epoch 17/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 189ms/step - accuracy: 0.9220 - loss: 0.1856 - val_accuracy: 0.9217 - val_loss: 0.2383
# Epoch 18/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 189ms/step - accuracy: 0.9484 - loss: 0.1296 - val_accuracy: 0.9304 - val_loss: 0.1527
# Epoch 19/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9612 - loss: 0.1062 - val_accuracy: 0.8935 - val_loss: 0.2595
# Epoch 20/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9538 - loss: 0.1379 - val_accuracy: 0.9413 - val_loss: 0.1809
# Epoch 21/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9685 - loss: 0.1028 - val_accuracy: 0.9043 - val_loss: 0.3552
# Epoch 22/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9457 - loss: 0.1272 - val_accuracy: 0.9478 - val_loss: 0.1886
# Epoch 23/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 191ms/step - accuracy: 0.9606 - loss: 0.1019 - val_accuracy: 0.9457 - val_loss: 0.1478
# Epoch 24/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9496 - loss: 0.1076 - val_accuracy: 0.9326 - val_loss: 0.2640
# Epoch 25/25
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 20s 188ms/step - accuracy: 0.9732 - loss: 0.0876 - val_accuracy: 0.8696 - val_loss: 0.3829

# %%
fishing_classification_model.save('fishing_classificaiton_model(base).keras')

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8, 6))
plt.plot(training_record.history['loss'], label='train loss')
plt.plot(training_record.history['val_loss'], label='val loss')
plt.title('train and val loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
y_pred = fishing_classification_model.predict(test_x).ravel()
fpr, tpr, thresholds = roc_curve(process2_y_test, y_pred)
auc_value = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_value:.2f}')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step

# %%
precision, recall, _ = precision_recall_curve(process2_y_test, y_pred)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='precision-recall curve')
plt.title('PRC Curve')
plt.xlabel('Recall')
plt.ylabel('Precisio')
plt.legend(loc='lower left')
plt.show()

# %%
y_pred_binary = np.where(y_pred > 0.5, 1, 0)  
accuracy = accuracy_score(process2_y_test, y_pred_binary)
print(f'accuracy score: {accuracy:.2f}')
# Out:
# accuracy score: 0.95

# %%
cm = confusion_matrix(process2_y_test, y_pred_binary)
fig, ax = plt.subplots(figsize=(6, 6))
cax = ax.matshow(cm, cmap=plt.cm.Blues)
fig.colorbar(cax)
plt.title('confusion matrix')
plt.xlabel('prediction value')
plt.ylabel('real value')
plt.xticks([0, 1], ['0', '1'])
plt.yticks([0, 1], ['0', '1'])
for (i, j), val in np.ndenumerate(cm):
    ax.text(j, i, f'{val}', ha='center', va='center')
plt.show()

# %%
print(classification_report(process2_y_test, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       100
#            1       0.94      0.99      0.97       200
#
#     accuracy                           0.95       300
#    macro avg       0.96      0.94      0.95       300
# weighted avg       0.95      0.95      0.95       300
