# 297         114 -0.010012 -0.703465 -0.350885  0.815017 -0.063878 -0.583349
# 298         212 -0.184607  0.220610  0.221541  0.074137 -0.665925 -0.805915
# 299           1  0.492194  0.212017 -0.066997  0.053507 -0.470779 -0.817170
#
#             6         7         8  ...       759       760       761  \
# 0    0.246801  1.128420 -0.149834  ...  0.592825  0.500640  0.605496
# 1    0.305553  0.219226 -0.376502  ...  0.337366 -0.338611  0.280206
# 2   -0.280904  0.131339  0.052337  ...  0.270138  0.223051  1.047092
# 3   -0.447116  0.502523  0.262692  ...  0.562066 -0.322386  0.485369
# 4    0.603051  0.444048 -0.069144  ...  0.666232 -0.090251  0.564425
# ..        ...       ...       ...  ...       ...       ...       ...
# 295 -0.023087  0.196514 -0.072020  ...  0.241416 -0.263029  0.704990
# 296  0.306810  0.293102  0.527462  ...  1.086128  0.309299  0.986482
# 297 -0.172727  0.571138 -0.063338  ...  0.452037  0.224393  0.736956
# 298  0.294412  0.324170  0.087962  ...  0.697795  0.145734  1.586126
# 299 -0.118232  0.099965 -0.415901  ...  0.282543 -0.253773  0.581378
#
#           762       763       764       765       766       767  predict
# 0    0.274810 -0.426490  0.086146 -0.354900 -0.387442  0.349690        1
# 1    0.313776 -0.630609  1.057353 -0.347879 -0.567393  1.539160        1
# 2    0.448527  0.259045  0.628844 -0.650998 -0.096991  0.466812        1
# 3    0.264875 -0.923644  0.986652 -0.807359  0.426340  1.188043        1
# 4    0.768610 -0.796792  0.713367 -0.325073 -0.580606  1.201177        1
# ..        ...       ...       ...       ...       ...       ...      ...
# 295  0.319108  0.212580 -0.275676  0.330456 -0.238615  0.310781        0
# 296 -0.342356 -0.733320 -0.393184 -0.124059 -0.355277  0.166317        1
# 297 -0.599168 -0.002092  0.165986 -0.055533 -0.349888  0.136336        0
# 298  0.179109 -0.405893  0.292017  0.040584  0.130968  0.705416        1
# 299 -0.670946 -0.144551  0.228544  0.211777 -1.031725  1.033660        1
#
# [300 rows x 770 columns]

# %%
process2_x_train=process2_train_row
process2_x_train=process2_x_train.drop(columns=['predict'])
process2_x_train=process2_x_train.drop(columns=['Unnamed: 0'])
process2_y_train=pd.DataFrame(process2_train_row['predict'])

# %%
process2_x_train
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.671553  0.199994 -0.475266  1.080652 -1.083905 -0.685691 -0.483161
# 1    -0.264695 -0.088437 -0.015752  0.419237  0.171373 -0.082314  0.496904
# 2     0.443137 -0.074751  0.002612  0.656167 -0.809256 -0.474835  0.456959
# 3     0.276542 -0.110308  0.197536  0.539801 -0.922572 -0.504065 -0.229346
# 4     0.376542 -0.353966 -0.214773  0.147485 -0.506191 -0.607935 -0.167980
# ...        ...       ...       ...       ...       ...       ...       ...
# 1527  0.029921 -0.187604 -0.250291  0.131767 -1.039377 -0.156767 -0.064283
# 1528  0.104737  1.080034 -0.246986  0.499492 -0.736370  0.190165 -0.331630
# 1529  0.530050 -0.040232 -0.603961  0.624902 -1.072392 -1.023183  0.162694
# 1530  0.382466  0.411182 -0.384856  0.675312 -0.653219 -0.480911  0.137235
# 1531 -0.297570  0.649419 -0.104644  0.331220 -0.793932  0.189841  0.409421
#
#              7         8         9  ...       758       759       760  \
# 0     1.192671 -0.173502 -0.740606  ... -0.338396  0.666164  0.558536
# 1     0.628129 -0.360460 -0.288529  ...  0.095381  0.688097  0.178779
# 2     0.593010 -0.043582 -0.447426  ...  0.002112  0.287520  0.938975
# 3     0.610395 -0.245753  0.379707  ...  0.184620  0.623498  0.138299
# 4    -0.119554  0.020818 -0.321772  ...  0.247156  0.129073  0.747620
# ...        ...       ...       ...  ...       ...       ...       ...
# 1527  0.745423  0.003185  0.710025  ... -0.140806  0.665829  0.570277
# 1528  0.544932 -0.080959 -0.260782  ... -0.130968  0.748832 -0.808843
# 1529  0.726400 -0.210569 -0.091726  ... -0.290204  0.500941  0.418125
# 1530  0.138352 -0.796327  0.113135  ...  0.122581  0.769422  0.469466
# 1531  0.404729  0.045529 -0.748183  ...  0.299167  0.907593  0.145814
#
#            761       762       763       764       765       766       767
# 0     1.099014 -0.798139  0.145339 -0.065750  0.332045 -1.037988  0.211755
# 1     1.430556 -0.298951 -0.380835  0.716058 -0.598559 -0.523293  0.251428
# 2     0.899574 -0.004223 -0.320927  0.369561 -0.030407 -0.097076  0.441640
# 3     1.350305  0.655737 -0.248328  0.390842 -0.105334 -0.284117  0.328432
# 4     0.134120 -0.438833 -1.010291  0.054258 -0.023663 -0.271083  0.397983
# ...        ...       ...       ...       ...       ...       ...       ...
# 1527 -0.171625  0.433920 -0.412372  0.334977 -0.909627 -0.313785  0.421041
# 1528  0.993277  0.868639 -0.130536  0.617157 -0.307037 -0.187114  0.749393
# 1529  1.098558  0.017224 -0.547468  0.057251 -0.337869 -0.802690  0.483136
# 1530  0.342500  0.346005 -0.287706 -0.359133 -0.726981 -0.355657  0.748789
# 1531  1.111604  0.118114 -0.480320  0.705528 -0.379175 -0.241494  0.814380
#
# [1532 rows x 768 columns]

# %%
process2_y_train
# Out:
#       predict
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ...       ...
# 1527        1
# 1528        1
# 1529        1
# 1530        1
# 1531        1
#
# [1532 rows x 1 columns]

# %%
process2_x_test=process2_test_row
process2_x_test=process2_x_test.drop(columns=['predict'])
process2_x_test=process2_x_test.drop(columns=['Unnamed: 0'])
process2_y_test=pd.DataFrame(process2_test_row['predict'])

# %%
process2_x_test
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.363420  0.730122  0.151181  0.507314  0.245331 -0.192631  0.246801
# 1   -0.857381  0.095771  0.456598  0.589936 -0.185549  0.065896  0.305553
# 2    0.179474 -0.117690 -0.040403  0.270527 -0.956704  0.307183 -0.280904
# 3   -0.695436 -0.036932  0.191028 -0.018038 -0.157643 -0.090875 -0.447116
# 4   -0.174728 -0.442657 -0.122642  0.808087 -0.949526 -0.002880  0.603051
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.703024  0.043034 -0.449081  0.369961 -0.956316 -0.721727 -0.023087
# 296  0.104970  0.203703  0.096283  0.903566 -0.772838 -0.467643  0.306810
# 297 -0.010012 -0.703465 -0.350885  0.815017 -0.063878 -0.583349 -0.172727
# 298 -0.184607  0.220610  0.221541  0.074137 -0.665925 -0.805915  0.294412
# 299  0.492194  0.212017 -0.066997  0.053507 -0.470779 -0.817170 -0.118232
#
#             7         8         9  ...       758       759       760  \
# 0    1.128420 -0.149834  0.106403  ... -0.226106  0.592825  0.500640
# 1    0.219226 -0.376502  0.571409  ...  0.459850  0.337366 -0.338611
# 2    0.131339  0.052337  0.431258  ... -0.049431  0.270138  0.223051
# 3    0.502523  0.262692  0.785634  ...  0.056547  0.562066 -0.322386
# 4    0.444048 -0.069144  0.375298  ...  0.484488  0.666232 -0.090251
# ..        ...       ...       ...  ...       ...       ...       ...
# 295  0.196514 -0.072020 -0.577474  ... -0.345342  0.241416 -0.263029
# 296  0.293102  0.527462  0.207893  ... -0.452835  1.086128  0.309299
# 297  0.571138 -0.063338 -0.092572  ... -0.149289  0.452037  0.224393
# 298  0.324170  0.087962  0.502689  ... -0.106637  0.697795  0.145734
# 299  0.099965 -0.415901 -0.681026  ... -0.034504  0.282543 -0.253773
#
#           761       762       763       764       765       766       767
# 0    0.605496  0.274810 -0.426490  0.086146 -0.354900 -0.387442  0.349690
# 1    0.280206  0.313776 -0.630609  1.057353 -0.347879 -0.567393  1.539160
# 2    1.047092  0.448527  0.259045  0.628844 -0.650998 -0.096991  0.466812
# 3    0.485369  0.264875 -0.923644  0.986652 -0.807359  0.426340  1.188043
# 4    0.564425  0.768610 -0.796792  0.713367 -0.325073 -0.580606  1.201177
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.704990  0.319108  0.212580 -0.275676  0.330456 -0.238615  0.310781
# 296  0.986482 -0.342356 -0.733320 -0.393184 -0.124059 -0.355277  0.166317
# 297  0.736956 -0.599168 -0.002092  0.165986 -0.055533 -0.349888  0.136336
# 298  1.586126  0.179109 -0.405893  0.292017  0.040584  0.130968  0.705416
# 299  0.581378 -0.670946 -0.144551  0.228544  0.211777 -1.031725  1.033660
#
# [300 rows x 768 columns]

# %%
process2_y_test
# Out:
#      predict
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 295        0
# 296        1
# 297        0
# 298        1
# 299        1
#
# [300 rows x 1 columns]

# %%
print(process2_x_train.shape)
print(process2_y_train.shape)
print(process2_x_test.shape)
print(process2_y_test.shape)
# Out:
# (1532, 768)
# (1532, 1)
# (300, 768)
# (300, 1)

# %%
import tensorflow as tf

x_train = tf.reshape(process2_x_train,(process2_x_train.shape[0],process2_x_train.shape[1],1))
test_x = tf.reshape(process2_x_test,(process2_x_test.shape[0],process2_x_test.shape[1],1))

# %%
print(x_train.shape)
print(process2_y_train.shape)
print(test_x.shape)
print(process2_y_test.shape)
# Out:
# (1532, 768, 1)
# (1532, 1)
# (300, 768, 1)
# (300, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional, Conv1D, MaxPooling1D, Flatten, GRU, ELU, Permute
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.regularizers import l2
import tensorflow as tf



fishing_classification_model = Sequential()

fishing_classification_model.add(Conv1D(filters=128, kernel_size=1, input_shape=(x_train.shape[1], x_train.shape[2])))
fishing_classification_model.add(ELU())

fishing_classification_model.add(Conv1D(filters=64, kernel_size=1))
fishing_classification_model.add(ELU())

fishing_classification_model.add(Conv1D(filters=32, kernel_size=1))
fishing_classification_model.add(ELU())

fishing_classification_model.add(MaxPooling1D(pool_size=1))

fishing_classification_model.add(Dropout(0.5))


fishing_classification_model.add(Permute((2, 1)))

fishing_classification_model.add(Bidirectional(LSTM(64, return_sequences=True)))
fishing_classification_model.add(Bidirectional(LSTM(32, return_sequences=False)))

fishing_classification_model.add(Dropout(0.5))

fishing_classification_model.add(Dense(16))
fishing_classification_model.add(ELU())

fishing_classification_model.add(Dropout(0.5))

fishing_classification_model.add(Dense(1, activation='sigmoid'))

fishing_classification_model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_fishing_classification_model_simplified.keras', save_best_only=True)

fishing_classification_model.summary()
# Out:
# /opt/anaconda3/envs/conda_cpu/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_3 (Conv1D)               │ (None, 768, 128)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_4 (ELU)                     │ (None, 768, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 768, 64)        │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_5 (ELU)                     │ (None, 768, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 768, 32)        │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_6 (ELU)                     │ (None, 768, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 768, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 768, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute_1 (Permute)             │ (None, 32, 768)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ (None, 32, 128)        │       426,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_7 (ELU)                     │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 479,361 (1.83 MB)
#  Trainable params: 479,361 (1.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
training_record = fishing_classification_model.fit(x_train, process2_y_train,
                    epochs=10,
                    batch_size=32,
                    callbacks=[early_stopping, model_checkpoint],
                    validation_split=0.3,
                    shuffle=True)
# Out:
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.7270 - loss: 0.4943 - val_accuracy: 0.9804 - val_loss: 0.0638
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9843 - loss: 0.0827 - val_accuracy: 0.9891 - val_loss: 0.0262
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9819 - loss: 0.0540 - val_accuracy: 0.9870 - val_loss: 0.0452
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9887 - loss: 0.0371 - val_accuracy: 0.9935 - val_loss: 0.0129
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9978 - val_loss: 0.0158
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9978 - val_loss: 0.0185
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9957 - val_loss: 0.0327
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9957 - val_loss: 0.0257
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9972 - loss: 0.0080 - val_accuracy: 0.9826 - val_loss: 0.0710
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.9952 - loss: 0.0139 - val_accuracy: 0.9913 - val_loss: 0.0194

# %%
fishing_classification_model.save('fishing_classificaiton_model(base).keras')

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8, 6))
plt.plot(training_record.history['loss'], label='train loss')
plt.plot(training_record.history['val_loss'], label='val loss')
plt.title('train and val loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
y_pred = fishing_classification_model.predict(test_x).ravel()
fpr, tpr, thresholds = roc_curve(process2_y_test, y_pred)
auc_value = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_value:.2f}')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step

# %%
precision, recall, _ = precision_recall_curve(process2_y_test, y_pred)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='precision-recall curve')
plt.title('PRC Curve')
plt.xlabel('Recall')
plt.ylabel('Precisio')
plt.legend(loc='lower left')
plt.show()

# %%
y_pred_binary = np.where(y_pred > 0.5, 1, 0)  
accuracy = accuracy_score(process2_y_test, y_pred_binary)
print(f'accuracy score: {accuracy:.2f}')
# Out:
# accuracy score: 0.99

# %%
cm = confusion_matrix(process2_y_test, y_pred_binary)
fig, ax = plt.subplots(figsize=(6, 6))
cax = ax.matshow(cm, cmap=plt.cm.Blues)
fig.colorbar(cax)
plt.title('confusion matrix')
plt.xlabel('prediction value')
plt.ylabel('real value')
plt.xticks([0, 1], ['0', '1'])
plt.yticks([0, 1], ['0', '1'])
for (i, j), val in np.ndenumerate(cm):
    ax.text(j, i, f'{val}', ha='center', va='center')
plt.show()

# %%
print(classification_report(process2_y_test, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       100
#            1       0.99      0.99      0.99       200
#
#     accuracy                           0.99       300
#    macro avg       0.99      0.99      0.99       300
# weighted avg       0.99      0.99      0.99       300
