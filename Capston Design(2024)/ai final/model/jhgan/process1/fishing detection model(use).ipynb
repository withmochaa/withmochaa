# %%
import pandas as pd 

process1_train_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/final/process1/NLP/jhgan/train/process1 train data after nlp(jhgan).csv")
process1_test_row=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/final/process1/NLP/jhgan/test/process1 test data after nlp(jhgan).csv")

# %%
process1_train_row
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0           1528 -0.232198  0.132130  0.096925  1.445417 -0.011512 -0.469353
# 1           3570  0.636589  0.854563 -0.192765  0.522641 -0.445347 -0.267390
# 2           1805  0.171878  0.163910 -0.078525  0.478400  0.250688 -0.322073
# 3           1069 -0.563278 -0.609890  0.112375  0.465317 -0.856890 -0.288381
# 4            479  0.160850 -0.027895 -0.539029  0.328565 -1.550965 -0.309774
# ...          ...       ...       ...       ...       ...       ...       ...
# 3775         472 -0.030886  0.687710 -0.727084  0.861790 -0.948694 -0.496047
# 3776        2144  0.489062  0.310772  0.003930  0.901179 -0.206107 -0.735598
# 3777        2111  0.510265 -0.091756 -0.465875  0.692877 -0.253145 -0.771298
# 3778        1335 -0.080096 -0.330203  0.586082  0.786734  0.179183 -0.699083
# 3779        1721 -0.131834  0.588638 -0.255511  0.991291 -0.798900 -0.565265
#
#              6         7         8  ...       759       760       761  \
# 0    -0.539951  0.568325  0.035491  ...  0.684869 -0.064352  0.386022
# 1    -0.379163  0.257799  0.932929  ...  0.096517 -0.087516 -0.561140
# 2    -0.430583  0.401242  0.048955  ...  0.068332  0.554532  0.341023
# 3    -0.479903  1.045721  0.095085  ...  0.813189  1.572031  0.367869
# 4     0.403868  0.986017 -0.349320  ...  1.040377 -1.201177  1.452310
# ...        ...       ...       ...  ...       ...       ...       ...
# 3775 -0.336143 -0.056612 -0.345357  ...  1.038163 -0.713042  0.666477
# 3776 -0.692768  0.431393  0.073107  ... -0.030165  0.389948 -0.149004
# 3777 -0.060198  0.109926  0.293678  ...  0.230531  0.375188 -0.219576
# 3778 -0.146289  0.622758  0.051669  ...  1.223011  0.827065  0.921351
# 3779 -0.127730  0.201873 -0.432611  ...  0.958875 -0.260548  0.779857
#
#            762       763       764       765       766       767  predict
# 0     0.726616 -0.476446  1.200558 -0.477488 -0.840568  1.032910        0
# 1    -0.127627  0.058762  1.123969 -0.260675 -0.844632  1.593512        0
# 2    -0.764928 -0.068300  0.676946 -0.070612  0.226067  0.531697        0
# 3     0.531527 -1.437005 -0.035752 -0.876054  0.185062 -0.200337        1
# 4     0.683493 -0.111253  0.090806 -0.159967 -0.366840  0.630569        1
# ...        ...       ...       ...       ...       ...       ...      ...
# 3775 -0.083109  0.180155  0.512022  0.151740 -1.114432  0.771864        1
# 3776 -0.071061  0.001911  0.389074  0.106334 -0.506428  0.789650        0
# 3777  0.034605 -0.328423  0.528637  0.051914 -0.388579  0.782643        0
# 3778 -0.159757 -0.007713  0.468975 -0.055247 -0.003393  1.135373        0
# 3779 -0.508400  0.397613  0.584964  0.535533 -0.433112  0.798310        1
#
# [3780 rows x 770 columns]

# %%
process1_test_row
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0            92 -0.857381  0.095771  0.456598  0.589936 -0.185549  0.065896
# 1           267  0.213626  0.313194  0.307273  0.829407 -0.835116 -0.023207
# 2            67  0.354462  0.573341 -0.235458  1.421009 -0.422881 -0.337639
# 3            47  0.190732  0.033536 -0.231045  0.564280 -0.069613 -0.467043
# 4           231 -0.140776  0.259568  0.470044  0.459235 -0.733617  0.786269
# ..          ...       ...       ...       ...       ...       ...       ...
# 295          61  0.650972  0.009062 -0.490738  0.926560 -0.526432 -0.872687
# 296          56  0.013617  0.576204 -0.069029  0.698993 -0.799966 -0.305333
# 297         280  0.837035 -0.296552 -0.454885  0.684314 -0.541675 -0.833938
# 298         142 -0.162835 -0.529347  0.393719  0.601195 -0.307332 -0.407340
# 299         190  0.371741  0.209442 -0.195443  0.853447 -1.086234 -0.467774
#
#             6         7         8  ...       759       760       761  \
# 0    0.305553  0.219226 -0.376502  ...  0.337366 -0.338611  0.280206
# 1   -0.204221  0.546537 -0.599047  ...  0.861644  0.633908  0.880952
# 2   -0.174043  0.296275  0.146487  ...  1.418881  0.298972  0.502824
# 3   -0.321804  0.590415  0.584884  ...  0.338336  0.620643  1.079729
# 4    0.561632 -0.147203  0.795936  ... -0.275491  0.818114  0.313283
# ..        ...       ...       ...  ...       ...       ...       ...
# 295  0.018627  0.355239 -0.051463  ...  0.903325  0.054412  0.845548
# 296 -0.108206  0.605805 -0.142084  ...  0.423321  0.354838  0.408441
# 297 -0.592240  0.770108 -0.351674  ...  0.879958  0.932553  0.951898
# 298 -0.351407  0.453178 -0.330072  ...  0.354541  0.122124  1.104730
# 299 -0.511348  0.665418  0.290279  ...  0.111854  0.420350 -0.161086
#
#           762       763       764       765       766       767  predict
# 0    0.313776 -0.630609  1.057353 -0.347879 -0.567393  1.539160        1
# 1   -0.342320 -0.315886  0.406749 -0.204448 -0.430718  0.726071        1
# 2    0.095571 -0.208813  1.010040  0.354238 -0.232382  0.667582        1
# 3   -0.573125  0.413144  1.149207 -0.293000 -0.976346  0.994887        0
# 4   -0.693431  0.729819  0.602322  0.442439 -0.090018  0.169040        0
# ..        ...       ...       ...       ...       ...       ...      ...
# 295  0.587932 -0.062323  0.763094  0.428923 -0.486567 -0.445700        0
# 296 -0.378468 -0.587194  0.444583 -0.111331 -0.725299  0.157710        1
# 297 -0.638577 -0.536742  0.376649 -0.096364 -0.439838 -0.299191        1
# 298  0.362784 -0.432228  0.714539 -0.381297  0.109006  0.276248        1
# 299  0.035567 -0.290424 -0.013632 -0.779436  0.052775  0.777563        0
#
# [300 rows x 770 columns]

# %%
process1_x_train=process1_train_row
process1_x_train=process1_x_train.drop(columns=['predict'])
process1_x_train=process1_x_train.drop(columns=['Unnamed: 0'])
process1_y_train=pd.DataFrame(process1_train_row['predict'])

# %%
process1_x_train
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.232198  0.132130  0.096925  1.445417 -0.011512 -0.469353 -0.539951
# 1     0.636589  0.854563 -0.192765  0.522641 -0.445347 -0.267390 -0.379163
# 2     0.171878  0.163910 -0.078525  0.478400  0.250688 -0.322073 -0.430583
# 3    -0.563278 -0.609890  0.112375  0.465317 -0.856890 -0.288381 -0.479903
# 4     0.160850 -0.027895 -0.539029  0.328565 -1.550965 -0.309774  0.403868
# ...        ...       ...       ...       ...       ...       ...       ...
# 3775 -0.030886  0.687710 -0.727084  0.861790 -0.948694 -0.496047 -0.336143
# 3776  0.489062  0.310772  0.003930  0.901179 -0.206107 -0.735598 -0.692768
# 3777  0.510265 -0.091756 -0.465875  0.692877 -0.253145 -0.771298 -0.060198
# 3778 -0.080096 -0.330203  0.586082  0.786734  0.179183 -0.699083 -0.146289
# 3779 -0.131834  0.588638 -0.255511  0.991291 -0.798900 -0.565265 -0.127730
#
#              7         8         9  ...       758       759       760  \
# 0     0.568325  0.035491 -0.686042  ... -0.112448  0.684869 -0.064352
# 1     0.257799  0.932929 -0.728307  ...  0.133716  0.096517 -0.087516
# 2     0.401242  0.048955 -0.709375  ...  0.230048  0.068332  0.554532
# 3     1.045721  0.095085  0.511692  ...  0.360468  0.813189  1.572031
# 4     0.986017 -0.349320  0.222773  ...  0.246446  1.040377 -1.201177
# ...        ...       ...       ...  ...       ...       ...       ...
# 3775 -0.056612 -0.345357 -0.867717  ...  0.604499  1.038163 -0.713042
# 3776  0.431393  0.073107 -0.807786  ... -0.064307 -0.030165  0.389948
# 3777  0.109926  0.293678 -0.429049  ...  0.254069  0.230531  0.375188
# 3778  0.622758  0.051669 -0.846641  ... -0.003796  1.223011  0.827065
# 3779  0.201873 -0.432611 -0.953648  ...  0.151452  0.958875 -0.260548
#
#            761       762       763       764       765       766       767
# 0     0.386022  0.726616 -0.476446  1.200558 -0.477488 -0.840568  1.032910
# 1    -0.561140 -0.127627  0.058762  1.123969 -0.260675 -0.844632  1.593512
# 2     0.341023 -0.764928 -0.068300  0.676946 -0.070612  0.226067  0.531697
# 3     0.367869  0.531527 -1.437005 -0.035752 -0.876054  0.185062 -0.200337
# 4     1.452310  0.683493 -0.111253  0.090806 -0.159967 -0.366840  0.630569
# ...        ...       ...       ...       ...       ...       ...       ...
# 3775  0.666477 -0.083109  0.180155  0.512022  0.151740 -1.114432  0.771864
# 3776 -0.149004 -0.071061  0.001911  0.389074  0.106334 -0.506428  0.789650
# 3777 -0.219576  0.034605 -0.328423  0.528637  0.051914 -0.388579  0.782643
# 3778  0.921351 -0.159757 -0.007713  0.468975 -0.055247 -0.003393  1.135373
# 3779  0.779857 -0.508400  0.397613  0.584964  0.535533 -0.433112  0.798310
#
# [3780 rows x 768 columns]

# %%
process1_y_train
# Out:
#       predict
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# ...       ...
# 3775        1
# 3776        0
# 3777        0
# 3778        0
# 3779        1
#
# [3780 rows x 1 columns]

# %%
process1_x_test=process1_test_row
process1_x_test=process1_x_test.drop(columns=['predict'])
process1_x_test=process1_x_test.drop(columns=['Unnamed: 0'])
process1_y_test=pd.DataFrame(process1_test_row['predict'])

# %%
process1_x_test
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.857381  0.095771  0.456598  0.589936 -0.185549  0.065896  0.305553
# 1    0.213626  0.313194  0.307273  0.829407 -0.835116 -0.023207 -0.204221
# 2    0.354462  0.573341 -0.235458  1.421009 -0.422881 -0.337639 -0.174043
# 3    0.190732  0.033536 -0.231045  0.564280 -0.069613 -0.467043 -0.321804
# 4   -0.140776  0.259568  0.470044  0.459235 -0.733617  0.786269  0.561632
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.650972  0.009062 -0.490738  0.926560 -0.526432 -0.872687  0.018627
# 296  0.013617  0.576204 -0.069029  0.698993 -0.799966 -0.305333 -0.108206
# 297  0.837035 -0.296552 -0.454885  0.684314 -0.541675 -0.833938 -0.592240
# 298 -0.162835 -0.529347  0.393719  0.601195 -0.307332 -0.407340 -0.351407
# 299  0.371741  0.209442 -0.195443  0.853447 -1.086234 -0.467774 -0.511348
#
#             7         8         9  ...       758       759       760  \
# 0    0.219226 -0.376502  0.571409  ...  0.459850  0.337366 -0.338611
# 1    0.546537 -0.599047 -0.693016  ... -0.076745  0.861644  0.633908
# 2    0.296275  0.146487  0.630844  ...  0.478998  1.418881  0.298972
# 3    0.590415  0.584884 -0.568049  ...  0.121466  0.338336  0.620643
# 4   -0.147203  0.795936 -0.610527  ... -0.407842 -0.275491  0.818114
# ..        ...       ...       ...  ...       ...       ...       ...
# 295  0.355239 -0.051463  0.286589  ...  0.135792  0.903325  0.054412
# 296  0.605805 -0.142084 -0.194340  ...  0.082529  0.423321  0.354838
# 297  0.770108 -0.351674 -0.148718  ... -0.112710  0.879958  0.932553
# 298  0.453178 -0.330072  0.376391  ...  0.234206  0.354541  0.122124
# 299  0.665418  0.290279 -0.960051  ... -0.174882  0.111854  0.420350
#
#           761       762       763       764       765       766       767
# 0    0.280206  0.313776 -0.630609  1.057353 -0.347879 -0.567393  1.539160
# 1    0.880952 -0.342320 -0.315886  0.406749 -0.204448 -0.430718  0.726071
# 2    0.502824  0.095571 -0.208813  1.010040  0.354238 -0.232382  0.667582
# 3    1.079729 -0.573125  0.413144  1.149207 -0.293000 -0.976346  0.994887
# 4    0.313283 -0.693431  0.729819  0.602322  0.442439 -0.090018  0.169040
# ..        ...       ...       ...       ...       ...       ...       ...
# 295  0.845548  0.587932 -0.062323  0.763094  0.428923 -0.486567 -0.445700
# 296  0.408441 -0.378468 -0.587194  0.444583 -0.111331 -0.725299  0.157710
# 297  0.951898 -0.638577 -0.536742  0.376649 -0.096364 -0.439838 -0.299191
# 298  1.104730  0.362784 -0.432228  0.714539 -0.381297  0.109006  0.276248
# 299 -0.161086  0.035567 -0.290424 -0.013632 -0.779436  0.052775  0.777563
#
# [300 rows x 768 columns]

# %%
process1_y_test
# Out:
#      predict
# 0          1
# 1          1
# 2          1
# 3          0
# 4          0
# ..       ...
# 295        0
# 296        1
# 297        1
# 298        1
# 299        0
#
# [300 rows x 1 columns]

# %%
print(process1_x_train.shape)
print(process1_y_train.shape)
print(process1_x_test.shape)
print(process1_y_test.shape)
# Out:
# (3780, 768)
# (3780, 1)
# (300, 768)
# (300, 1)

# %%
import tensorflow as tf

x_train = tf.reshape(process1_x_train,(process1_x_train.shape[0],process1_x_train.shape[1],1))
test_x = tf.reshape(process1_x_test,(process1_x_test.shape[0],process1_x_test.shape[1],1))

# %%
print(x_train.shape)
print(process1_y_train.shape)
print(test_x.shape)
print(process1_y_test.shape)
# Out:
# (3780, 768, 1)
# (3780, 1)
# (300, 768, 1)
# (300, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional, Conv1D, MaxPooling1D, Flatten,ELU,Permute
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler
import tensorflow as tf
from tensorflow.keras.activations import elu


def lr_schedule(epoch, lr):
    if epoch > 5:
        return float(lr * tf.math.exp(-0.1))  
    return float(lr)  

fishing_detection_model = tf.keras.Sequential()

fishing_detection_model.add(Conv1D(filters=128, kernel_size=1, input_shape=(x_train.shape[1], x_train.shape[2])))
fishing_detection_model.add(ELU())

fishing_detection_model.add(Conv1D(filters=64, kernel_size=1))
fishing_detection_model.add(ELU())

fishing_detection_model.add(Conv1D(filters=32, kernel_size=1))
fishing_detection_model.add(ELU())

fishing_detection_model.add(MaxPooling1D(pool_size=1))

fishing_detection_model.add(Dropout(0.5))


fishing_detection_model.add(Permute((2, 1)))

fishing_detection_model.add(Bidirectional(LSTM(128, return_sequences=True)))
fishing_detection_model.add(Bidirectional(LSTM(64, return_sequences=True)))
fishing_detection_model.add(Bidirectional(LSTM(32, return_sequences=True)))
fishing_detection_model.add(Bidirectional(LSTM(16, return_sequences=False)))

fishing_detection_model.add(Dropout(0.5))

fishing_detection_model.add(Dense(128))
fishing_detection_model.add(ELU())

fishing_detection_model.add(Dropout(0.5))

fishing_detection_model.add(Dense(1, activation='sigmoid'))

fishing_detection_model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_fishing_detection_model.keras', save_best_only=True)
lr_scheduler = LearningRateScheduler(lr_schedule)

fishing_detection_model.summary()
# Out:
# /opt/anaconda3/envs/conda_cpu/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_45 (Conv1D)              │ (None, 768, 128)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_60 (ELU)                    │ (None, 768, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_46 (Conv1D)              │ (None, 768, 64)        │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_61 (ELU)                    │ (None, 768, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_47 (Conv1D)              │ (None, 768, 32)        │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_62 (ELU)                    │ (None, 768, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_15 (MaxPooling1D) │ (None, 768, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_46 (Dropout)            │ (None, 768, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute_15 (Permute)            │ (None, 32, 768)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_32                │ (None, 32, 256)        │       918,528 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_33                │ (None, 32, 128)        │       164,352 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_34                │ (None, 32, 64)         │        41,216 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_35                │ (None, 32)             │        10,368 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_47 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_63 (ELU)                    │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_48 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,149,409 (4.38 MB)
#  Trainable params: 1,149,409 (4.38 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
training_record = fishing_detection_model.fit(x_train, process1_y_train,
                    epochs=10,
                    batch_size=32,
                    callbacks=[early_stopping, model_checkpoint,lr_scheduler],
                    validation_split=0.3,
                    shuffle=True)
# Out:
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.8485 - loss: 0.3305 - val_accuracy: 0.9815 - val_loss: 0.1021 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 173ms/step - accuracy: 0.9868 - loss: 0.0706 - val_accuracy: 0.9885 - val_loss: 0.0504 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 13s 152ms/step - accuracy: 0.9960 - loss: 0.0161 - val_accuracy: 0.9991 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 1.0000 - loss: 8.7935e-04 - val_accuracy: 1.0000 - val_loss: 2.7992e-04 - learning_rate: 0.0010
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 15s 180ms/step - accuracy: 0.9981 - loss: 0.0079 - val_accuracy: 0.9965 - val_loss: 0.0104 - learning_rate: 0.0010
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9986 - loss: 0.0088 - val_accuracy: 0.9974 - val_loss: 0.0104 - learning_rate: 0.0010
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.9974 - loss: 0.0062 - val_accuracy: 0.9991 - val_loss: 0.0033 - learning_rate: 9.0484e-04
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9978 - loss: 0.0057 - val_accuracy: 0.9982 - val_loss: 0.0049 - learning_rate: 8.1873e-04
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9994 - loss: 0.0040 - val_accuracy: 0.9991 - val_loss: 0.0025 - learning_rate: 7.4082e-04
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 1.0000 - loss: 4.5549e-04 - val_accuracy: 0.9991 - val_loss: 0.0019 - learning_rate: 6.7032e-04

# %%
fishing_detection_model.save('fishing_detection_model(jhgan).keras')

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve, accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8, 6))
plt.plot(training_record.history['loss'], label='train loss')
plt.plot(training_record.history['val_loss'], label='val loss')
plt.title('train and val loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
y_pred = fishing_detection_model.predict(test_x).ravel()
fpr, tpr, thresholds = roc_curve(process1_y_test, y_pred)
auc_value = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc_value:.2f}')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step

# %%
precision, recall, _ = precision_recall_curve(process1_y_test, y_pred)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, label='precision-recall curve')
plt.title('PRC Curve')
plt.xlabel('Recall')
plt.ylabel('Precisio')
plt.legend(loc='lower left')
plt.show()

# %%
y_pred_binary = np.where(y_pred > 0.5, 1, 0)  
accuracy = accuracy_score(process1_y_test, y_pred_binary)
print(f'accuracy score: {accuracy:.2f}')
# Out:
# accuracy score: 1.00

# %%
cm = confusion_matrix(process1_y_test, y_pred_binary)
fig, ax = plt.subplots(figsize=(6, 6))
cax = ax.matshow(cm, cmap=plt.cm.Blues)
fig.colorbar(cax)
plt.title('confusion matrix')
plt.xlabel('prediction value')
plt.ylabel('real value')
plt.xticks([0, 1], ['0', '1'])
plt.yticks([0, 1], ['0', '1'])
for (i, j), val in np.ndenumerate(cm):
    ax.text(j, i, f'{val}', ha='center', va='center')
plt.show()

# %%
print(classification_report(process1_y_test, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       158
#            1       1.00      1.00      1.00       142
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
